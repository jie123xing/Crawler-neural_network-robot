# %%
import csv

import pandas as pd

import numpy as np

import torch

from torch import nn, optim

from torch.autograd import Variable

from torch.utils.data import Dataset

from torch.utils.data import DataLoader

import time

# %%
# 定义自己的类
class MyDataset(Dataset):
    
    # 初始化
    def __init__(self, file_name):
        # 读入数据
        self.data = pd.read_csv(file_name)
    
    # 返回df的长度
    def __len__(self):
        return len(self.data)
    
    # 获取第idx+1列的数据
    def __getitem__(self, idx):
        return self.data.values[idx,1:10]

# 通过实例化对象来访问该类
# 假设同目录下存在名为median_benchmark.csv的文件
ds = MyDataset('formatweather.csv')
ds=np.asarray(ds[:], dtype = np.float32)#####源文件float32 ,不知道为什么读取变为float64，这里再进行处理  最大最小化时变化
##dl = DataLoader(ds, batch_size=100, shuffle=False)

#####处理为torch，分为trainx，trainy
torchds=torch.from_numpy(ds[:])

# %%
train_dataset =torchds[:30700]  ##0.7*43823
test_dataset =torchds[30700:]
dl = DataLoader(train_dataset, batch_size=100, shuffle=False)

# %%
# 定义 Recurrent Network 模型

class Rnn(nn.Module):

    def __init__(self, in_dim, hidden_dim, n_layer, n_class):

        super(Rnn, self).__init__()

        self.n_layer = n_layer

        self.hidden_dim = hidden_dim

        self.lstm = nn.LSTM(in_dim, hidden_dim, n_layer, batch_first=True)

        self.classifier = nn.Linear(hidden_dim, n_class)



    def forward(self, x):

        # h0 = Variable(torch.zeros(self.n_layer, x.size(1),

        #   self.hidden_dim)).cuda()

        # c0 = Variable(torch.zeros(self.n_layer, x.size(1),

        #   self.hidden_dim)).cuda()

        out, _ = self.lstm(x) #out 100 28 128 _ [0]2 100 128 [1]2 100 128

        out = out[:, -1, :]  #100,128

        out = self.classifier(out) #100,10

        return out

# %%
model = Rnn(8, 4, 2, 1)  
##model.load_state_dict(torch.load('./weathercnn.pth'))
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01) ####速度很快

# %%
# %%time 
losslist=[]
for epoch in range(1000):
 
    print('epoch {}'.format(epoch + 1))

    print('*' * 10)

    running_loss = 0.0

    for i, data in enumerate(dl, 1):
        
            train_x=data[:,0:8]
            
            train_x=train_x.view(-1,1,8)
            
            train_y=data[:,8]
            
            train_y=train_y.view(-1,1)
            
            train_x=Variable(train_x)
            
            train_y=Variable(train_y)
        
            out = model(train_x)

            loss = criterion(out, train_y)
            
            running_loss += loss.item() * train_y.size(0)
            

            # 向后传播

            optimizer.zero_grad()

            loss.backward()

            optimizer.step()
            
    losslist.append(running_loss / (len(train_dataset)))   
           
                
    print('running_loss:-------')
    print(running_loss / (len(train_dataset)))            
    #print(out,train_y)
# Out:
# epoch 1
# **********
# running_loss:-------
# 0.00864424504347125
# epoch 2
# **********
# running_loss:-------
# 0.008465302365998809
# epoch 3
# **********
# running_loss:-------
# 0.008461952158982369
# epoch 4
# **********
# running_loss:-------
# 0.00845858424589345
# epoch 5
# **********
# running_loss:-------
# 0.008455258950126493
# epoch 6
# **********
# running_loss:-------
# 0.008451975195796666
# epoch 7
# **********
# running_loss:-------
# 0.00844873200259607
# epoch 8
# **********
# running_loss:-------
# 0.008445528771573563
# epoch 9
# **********
# running_loss:-------
# 0.008442363791308966
# epoch 10
# **********
# running_loss:-------
# 0.00843923697079356
# epoch 11
# **********
# running_loss:-------
# 0.008436146906955495
# epoch 12
# **********
# running_loss:-------
# 0.008433093042253785
# epoch 13
# **********
# running_loss:-------
# 0.008430074261816786
# epoch 14
# **********
# running_loss:-------
# 0.00842708975333538
# epoch 15
# **********
# running_loss:-------
# 0.008424138737345946
# epoch 16
# **********
# running_loss:-------
# 0.008421220187502966
# epoch 17
# **********
# running_loss:-------
# 0.008418333972501479
# epoch 18
# **********
# running_loss:-------
# 0.008415478789213325
# epoch 19
# **********
# running_loss:-------
# 0.008412654070069376
# epoch 20
# **********
# running_loss:-------
# 0.008409858746543706
# epoch 21
# **********
# running_loss:-------
# 0.008407092601800337
# epoch 22
# **********
# running_loss:-------
# 0.00840435447189639
# epoch 23
# **********
# running_loss:-------
# 0.008401643963645749
# epoch 24
# **********
# running_loss:-------
# 0.008398960685435402
# epoch 25
# **********
# running_loss:-------
# 0.00839630382036728
# epoch 26
# **********
# running_loss:-------
# 0.008393671892556636
# epoch 27
# **********
# running_loss:-------
# 0.008391065560996074
# epoch 28
# **********
# running_loss:-------
# 0.008388483549217188
# epoch 29
# **********
# running_loss:-------
# 0.008385925518807957
# epoch 30
# **********
# running_loss:-------
# 0.008383390520211477
# epoch 31
# **********
# running_loss:-------
# 0.008380878343609987
# epoch 32
# **********
# running_loss:-------
# 0.008378388175767098
# epoch 33
# **********
# running_loss:-------
# 0.008375919395157236
# epoch 34
# **********
# running_loss:-------
# 0.008373471901487134
# epoch 35
# **********
# running_loss:-------
# 0.008371044923531946
# epoch 36
# **********
# running_loss:-------
# 0.008368637787492375
# epoch 37
# **********
# running_loss:-------
# 0.008366249882703462
# epoch 38
# **********
# running_loss:-------
# 0.008363881183400137
# epoch 39
# **********
# running_loss:-------
# 0.008361530952026637
# epoch 40
# **********
# running_loss:-------
# 0.008359198829279229
# epoch 41
# **********
# running_loss:-------
# 0.0083568845388078
# epoch 42
# **********
# running_loss:-------
# 0.008354586903030013
# epoch 43
# **********
# running_loss:-------
# 0.008352306134566174
# epoch 44
# **********
# running_loss:-------
# 0.008350041367758045
# epoch 45
# **********
# running_loss:-------
# 0.008347792520795538
# epoch 46
# **********
# running_loss:-------
# 0.008345558918024817
# epoch 47
# **********
# running_loss:-------
# 0.008343340194193402
# epoch 48
# **********
# running_loss:-------
# 0.00834113574157219
# epoch 49
# **********
# running_loss:-------
# 0.008338945641790557
# epoch 50
# **********
# running_loss:-------
# 0.008336769390739584
# epoch 51
# **********
# running_loss:-------
# 0.008334606020100704
# epoch 52
# **********
# running_loss:-------
# 0.00833245561892737
# epoch 53
# **********
# running_loss:-------
# 0.008330317661152446
# epoch 54
# **********
# running_loss:-------
# 0.008328191849107495
# epoch 55
# **********
# running_loss:-------
# 0.008326077721746844
# epoch 56
# **********
# running_loss:-------
# 0.008323974883555836
# epoch 57
# **********
# running_loss:-------
# 0.008321883318116164
# epoch 58
# **********
# running_loss:-------
# 0.008319802075346558
# epoch 59
# **********
# running_loss:-------
# 0.00831773105852655
# epoch 60
# **********
# running_loss:-------
# 0.008315670143739708
# epoch 61
# **********
# running_loss:-------
# 0.00831361884727113
# epoch 62
# **********
# running_loss:-------
# 0.008311576608907627
# epoch 63
# **********
# running_loss:-------
# 0.008309543357560487
# epoch 64
# **********
# running_loss:-------
# 0.00830751862021544
# epoch 65
# **********
# running_loss:-------
# 0.00830550238166289
# epoch 66
# **********
# running_loss:-------
# 0.008303493983855277
# epoch 67
# **********
# running_loss:-------
# 0.008301493205883151
# epoch 68
# **********
# running_loss:-------
# 0.008299499549722616
# epoch 69
# **********
# running_loss:-------
# 0.008297512886995687
# epoch 70
# **********
# running_loss:-------
# 0.008295532997503914
# epoch 71
# **********
# running_loss:-------
# 0.00829355920370041
# epoch 72
# **********
# running_loss:-------
# 0.00829159137996233
# epoch 73
# **********
# running_loss:-------
# 0.008289629823235249
# epoch 74
# **********
# running_loss:-------
# 0.008287673317385513
# epoch 75
# **********
# running_loss:-------
# 0.008285721839275815
# epoch 76
# **********
# running_loss:-------
# 0.008283775530360723
# epoch 77
# **********
# running_loss:-------
# 0.008281833444345068
# epoch 78
# **********
# running_loss:-------
# 0.008279895703349997
# epoch 79
# **********
# running_loss:-------
# 0.008277961567147543
# epoch 80
# **********
# running_loss:-------
# 0.008276031374721495
# epoch 81
# **********
# running_loss:-------
# 0.008274104695960842
# epoch 82
# **********
# running_loss:-------
# 0.00827218058461782
# epoch 83
# **********
# running_loss:-------
# 0.008270259496020433
# epoch 84
# **********
# running_loss:-------
# 0.00826834109469845
# epoch 85
# **********
# running_loss:-------
# 0.008266424892445782
# epoch 86
# **********
# running_loss:-------
# 0.008264510499815017
# epoch 87
# **********
# running_loss:-------
# 0.008262598115265604
# epoch 88
# **********
# running_loss:-------
# 0.008260686599908721
# epoch 89
# **********
# running_loss:-------
# 0.008258776006933519
# epoch 90
# **********
# running_loss:-------
# 0.008256866371522923
# epoch 91
# **********
# running_loss:-------
# 0.008254957242508314
# epoch 92
# **********
# running_loss:-------
# 0.008253048665838427
# epoch 93
# **********
# running_loss:-------
# 0.008251140120837917
# epoch 94
# **********
# running_loss:-------
# 0.008249231065779742
# epoch 95
# **********
# running_loss:-------
# 0.008247321665504632
# epoch 96
# **********
# running_loss:-------
# 0.008245411221479185
# epoch 97
# **********
# running_loss:-------
# 0.008243499579693652
# epoch 98
# **********
# running_loss:-------
# 0.0082415866158761
# epoch 99
# **********
# running_loss:-------
# 0.008239671895104389
# epoch 100
# **********
# running_loss:-------
# 0.008237755265365508
# epoch 101
# **********
# running_loss:-------
# 0.00823583624003536
# epoch 102
# **********
# running_loss:-------
# 0.008233915139629355
# epoch 103
# **********
# running_loss:-------
# 0.008231990964254352
# epoch 104
# **********
# running_loss:-------
# 0.008230063763319315
# epoch 105
# **********
# running_loss:-------
# 0.008228133202811575
# epoch 106
# **********
# running_loss:-------
# 0.008226199016992779
# epoch 107
# **********
# running_loss:-------
# 0.008224261084049887
# epoch 108
# **********
# running_loss:-------
# 0.00822231899231064
# epoch 109
# **********
# running_loss:-------
# 0.00822037239268312
# epoch 110
# **********
# running_loss:-------
# 0.008218421028043994
# epoch 111
# **********
# running_loss:-------
# 0.00821646476680982
# epoch 112
# **********
# running_loss:-------
# 0.0082145030755901
# epoch 113
# **********
# running_loss:-------
# 0.00821253552601579
# epoch 114
# **********
# running_loss:-------
# 0.008210562455198361
# epoch 115
# **********
# running_loss:-------
# 0.008208583368621547
# epoch 116
# **********
# running_loss:-------
# 0.008206597353389668
# epoch 117
# **********
# running_loss:-------
# 0.008204604614378998
# epoch 118
# **********
# running_loss:-------
# 0.00820260498182509
# epoch 119
# **********
# running_loss:-------
# 0.008200597898595787
# epoch 120
# **********
# running_loss:-------
# 0.008198583303911954
# epoch 121
# **********
# running_loss:-------
# 0.008196560485002297
# epoch 122
# **********
# running_loss:-------
# 0.008194529735464744
# epoch 123
# **********
# running_loss:-------
# 0.008192490226586678
# epoch 124
# **********
# running_loss:-------
# 0.008190441951435798
# epoch 125
# **********
# running_loss:-------
# 0.008188384495792074
# epoch 126
# **********
# running_loss:-------
# 0.008186317695223601
# epoch 127
# **********
# running_loss:-------
# 0.008184240863266298
# epoch 128
# **********
# running_loss:-------
# 0.008182154161851692
# epoch 129
# **********
# running_loss:-------
# 0.008180056969738616
# epoch 130
# **********
# running_loss:-------
# 0.008177948748553607
# epoch 131
# **********
# running_loss:-------
# 0.008175829739410525
# epoch 132
# **********
# running_loss:-------
# 0.008173698864839589
# epoch 133
# **********
# running_loss:-------
# 0.008171556723661587
# epoch 134
# **********
# running_loss:-------
# 0.008169402301970642
# epoch 135
# **********
# running_loss:-------
# 0.008167235666553885
# epoch 136
# **********
# running_loss:-------
# 0.008165056149788878
# epoch 137
# **********
# running_loss:-------
# 0.008162863611903763
# epoch 138
# **********
# running_loss:-------
# 0.008160657516859546
# epoch 139
# **********
# running_loss:-------
# 0.00815843734191304
# epoch 140
# **********
# running_loss:-------
# 0.008156203064928267
# epoch 141
# **********
# running_loss:-------
# 0.008153954868716626
# epoch 142
# **********
# running_loss:-------
# 0.008151690854573132
# epoch 143
# **********
# running_loss:-------
# 0.008149412052176137
# epoch 144
# **********
# running_loss:-------
# 0.008147117430851883
# epoch 145
# **********
# running_loss:-------
# 0.008144806759274684
# epoch 146
# **********
# running_loss:-------
# 0.00814247949544495
# epoch 147
# **********
# running_loss:-------
# 0.008140135526277239
# epoch 148
# **********
# running_loss:-------
# 0.008137774030121588
# epoch 149
# **********
# running_loss:-------
# 0.008135395148693275
# epoch 150
# **********
# running_loss:-------
# 0.008132998264057304
# epoch 151
# **********
# running_loss:-------
# 0.008130582784846595
# epoch 152
# **********
# running_loss:-------
# 0.00812814860839193
# epoch 153
# **********
# running_loss:-------
# 0.008125694898515144
# epoch 154
# **********
# running_loss:-------
# 0.008123221160000811
# epoch 155
# **********
# running_loss:-------
# 0.008120727579701212
# epoch 156
# **********
# running_loss:-------
# 0.008118213560774521
# epoch 157
# **********
# running_loss:-------
# 0.008115678247857265
# epoch 158
# **********
# running_loss:-------
# 0.00811312137139536
# epoch 159
# **********
# running_loss:-------
# 0.008110542163656776
# epoch 160
# **********
# running_loss:-------
# 0.00810794085519694
# epoch 161
# **********
# running_loss:-------
# 0.008105316407106274
# epoch 162
# **********
# running_loss:-------
# 0.008102668571812617
# epoch 163
# **********
# running_loss:-------
# 0.008099996405728548
# epoch 164
# **********
# running_loss:-------
# 0.00809730029542783
# epoch 165
# **********
# running_loss:-------
# 0.008094579082634888
# epoch 166
# **********
# running_loss:-------
# 0.008091832348117105
# epoch 167
# **********
# running_loss:-------
# 0.008089059692727768
# epoch 168
# **********
# running_loss:-------
# 0.008086260315293886
# epoch 169
# **********
# running_loss:-------
# 0.008083433713217425
# epoch 170
# **********
# running_loss:-------
# 0.008080580017086425
# epoch 171
# **********
# running_loss:-------
# 0.008077697684788918
# epoch 172
# **********
# running_loss:-------
# 0.008074786590796865
# epoch 173
# **********
# running_loss:-------
# 0.00807184628602726
# epoch 174
# **********
# running_loss:-------
# 0.00806887582223559
# epoch 175
# **********
# running_loss:-------
# 0.008065874677247474
# epoch 176
# **********
# running_loss:-------
# 0.008062842629489857
# epoch 177
# **********
# running_loss:-------
# 0.008059778699552484
# epoch 178
# **********
# running_loss:-------
# 0.008056682041670454
# epoch 179
# **********
# running_loss:-------
# 0.008053552426982911
# epoch 180
# **********
# running_loss:-------
# 0.008050389022558604
# epoch 181
# **********
# running_loss:-------
# 0.008047191373567235
# epoch 182
# **********
# running_loss:-------
# 0.008043958514083953
# epoch 183
# **********
# running_loss:-------
# 0.008040690208659246
# epoch 184
# **********
# running_loss:-------
# 0.008037385217607395
# epoch 185
# **********
# running_loss:-------
# 0.008034042897112804
# epoch 186
# **********
# running_loss:-------
# 0.008030662615944675
# epoch 187
# **********
# running_loss:-------
# 0.00802724400716485
# epoch 188
# **********
# running_loss:-------
# 0.008023786011635644
# epoch 189
# **********
# running_loss:-------
# 0.008020287548735149
# epoch 190
# **********
# running_loss:-------
# 0.008016748283923366
# epoch 191
# **********
# running_loss:-------
# 0.008013167047039083
# epoch 192
# **********
# running_loss:-------
# 0.008009543347263259
# epoch 193
# **********
# running_loss:-------
# 0.008005876136016641
# epoch 194
# **********
# running_loss:-------
# 0.008002164658661557
# epoch 195
# **********
# running_loss:-------
# 0.00799840797148023
# epoch 196
# **********
# running_loss:-------
# 0.00799460537572003
# epoch 197
# **********
# running_loss:-------
# 0.00799075519209231
# epoch 198
# **********
# running_loss:-------
# 0.007986857690340752
# epoch 199
# **********
# running_loss:-------
# 0.007982911573863643
# epoch 200
# **********
# running_loss:-------
# 0.007978916288633545
# epoch 201
# **********
# running_loss:-------
# 0.007974869631729862
# epoch 202
# **********
# running_loss:-------
# 0.007970772082038589
# epoch 203
# **********
# running_loss:-------
# 0.007966621274612798
# epoch 204
# **********
# running_loss:-------
# 0.007962416653517188
# epoch 205
# **********
# running_loss:-------
# 0.007958157818171186
# epoch 206
# **********
# running_loss:-------
# 0.007953843061521373
# epoch 207
# **********
# running_loss:-------
# 0.007949471109931517
# epoch 208
# **********
# running_loss:-------
# 0.007945041605196981
# epoch 209
# **********
# running_loss:-------
# 0.007940553131160448
# epoch 210
# **********
# running_loss:-------
# 0.007936004328319908
# epoch 211
# **********
# running_loss:-------
# 0.007931394054918817
# epoch 212
# **********
# running_loss:-------
# 0.00792672068754172
# epoch 213
# **********
# running_loss:-------
# 0.007921984083513488
# epoch 214
# **********
# running_loss:-------
# 0.007917182497303448
# epoch 215
# **********
# running_loss:-------
# 0.007912314317997998
# epoch 216
# **********
# running_loss:-------
# 0.00790737906417522
# epoch 217
# **********
# running_loss:-------
# 0.0079023748519783
# epoch 218
# **********
# running_loss:-------
# 0.007897300477354754
# epoch 219
# **********
# running_loss:-------
# 0.007892154382159445
# epoch 220
# **********
# running_loss:-------
# 0.007886935700932617
# epoch 221
# **********
# running_loss:-------
# 0.007881642193733983
# epoch 222
# **********
# running_loss:-------
# 0.00787627254002464
# epoch 223
# **********
# running_loss:-------
# 0.007870826301517015
# epoch 224
# **********
# running_loss:-------
# 0.007865300742356245
# epoch 225
# **********
# running_loss:-------
# 0.007859695542447594
# epoch 226
# **********
# running_loss:-------
# 0.00785400779798482
# epoch 227
# **********
# running_loss:-------
# 0.00784823666257497
# epoch 228
# **********
# running_loss:-------
# 0.007842380136171058
# epoch 229
# **********
# running_loss:-------
# 0.00783643679402445
# epoch 230
# **********
# running_loss:-------
# 0.007830404988972106
# epoch 231
# **********
# running_loss:-------
# 0.007824282985484833
# epoch 232
# **********
# running_loss:-------
# 0.007818069022769034
# epoch 233
# **********
# running_loss:-------
# 0.007811760804122477
# epoch 234
# **********
# running_loss:-------
# 0.00780535680774426
# epoch 235
# **********
# running_loss:-------
# 0.007798855401615761
# epoch 236
# **********
# running_loss:-------
# 0.007792254716609828
# epoch 237
# **********
# running_loss:-------
# 0.00778555303992575
# epoch 238
# **********
# running_loss:-------
# 0.007778747548598622
# epoch 239
# **********
# running_loss:-------
# 0.007771836908224929
# epoch 240
# **********
# running_loss:-------
# 0.0077648186319558285
# epoch 241
# **********
# running_loss:-------
# 0.007757691819871493
# epoch 242
# **********
# running_loss:-------
# 0.007750452760024833
# epoch 243
# **********
# running_loss:-------
# 0.007743099492434026
# epoch 244
# **********
# running_loss:-------
# 0.0077356301261558985
# epoch 245
# **********
# running_loss:-------
# 0.007728042781244166
# epoch 246
# **********
# running_loss:-------
# 0.007720334953205195
# epoch 247
# **********
# running_loss:-------
# 0.007712503493480905
# epoch 248
# **********
# running_loss:-------
# 0.007704546622613806
# epoch 249
# **********
# running_loss:-------
# 0.007696461977778137
# epoch 250
# **********
# running_loss:-------
# 0.007688246674056704
# epoch 251
# **********
# running_loss:-------
# 0.00767989857993758
# epoch 252
# **********
# running_loss:-------
# 0.007671414934550352
# epoch 253
# **********
# running_loss:-------
# 0.007662793228649501
# epoch 254
# **********
# running_loss:-------
# 0.007654031265725333
# epoch 255
# **********
# running_loss:-------
# 0.0076451250160467915
# epoch 256
# **********
# running_loss:-------
# 0.007636071772945792
# epoch 257
# **********
# running_loss:-------
# 0.007626869798084669
# epoch 258
# **********
# running_loss:-------
# 0.007617515919074804
# epoch 259
# **********
# running_loss:-------
# 0.007608006722176716
# epoch 260
# **********
# running_loss:-------
# 0.007598339914574996
# epoch 261
# **********
# running_loss:-------
# 0.007588511792842772
# epoch 262
# **********
# running_loss:-------
# 0.007578519636198498
# epoch 263
# **********
# running_loss:-------
# 0.007568360319523579
# epoch 264
# **********
# running_loss:-------
# 0.0075580307328912385
# epoch 265
# **********
# running_loss:-------
# 0.007547527401984316
# epoch 266
# **********
# running_loss:-------
# 0.007536847592275157
# epoch 267
# **********
# running_loss:-------
# 0.007525987087239675
# epoch 268
# **********
# running_loss:-------
# 0.0075149426711890056
# epoch 269
# **********
# running_loss:-------
# 0.007503710909006099
# epoch 270
# **********
# running_loss:-------
# 0.007492288485650904
# epoch 271
# **********
# running_loss:-------
# 0.007480671813708964
# epoch 272
# **********
# running_loss:-------
# 0.007468857241585716
# epoch 273
# **********
# running_loss:-------
# 0.007456840463940616
# epoch 274
# **********
# running_loss:-------
# 0.007444618531534162
# epoch 275
# **********
# running_loss:-------
# 0.0074321877654336226
# epoch 276
# **********
# running_loss:-------
# 0.0074195438056221235
# epoch 277
# **********
# running_loss:-------
# 0.007406682947523329
# epoch 278
# **********
# running_loss:-------
# 0.007393601337581527
# epoch 279
# **********
# running_loss:-------
# 0.007380294153294378
# epoch 280
# **********
# running_loss:-------
# 0.007366759018433668
# epoch 281
# **********
# running_loss:-------
# 0.007352992005522798
# epoch 282
# **********
# running_loss:-------
# 0.007338986886875304
# epoch 283
# **********
# running_loss:-------
# 0.00732474102890263
# epoch 284
# **********
# running_loss:-------
# 0.007310249800137805
# epoch 285
# **********
# running_loss:-------
# 0.007295509567365759
# epoch 286
# **********
# running_loss:-------
# 0.007280515652690849
# epoch 287
# **********
# running_loss:-------
# 0.007265263042456876
# epoch 288
# **********
# running_loss:-------
# 0.007249748065907672
# epoch 289
# **********
# running_loss:-------
# 0.007233966313315221
# epoch 290
# **********
# running_loss:-------
# 0.007217912567225406
# epoch 291
# **********
# running_loss:-------
# 0.007201582984866101
# epoch 292
# **********
# running_loss:-------
# 0.007184973688222998
# epoch 293
# **********
# running_loss:-------
# 0.007168080327885054
# epoch 294
# **********
# running_loss:-------
# 0.007150898052803059
# epoch 295
# **********
# running_loss:-------
# 0.0071334213583951235
# epoch 296
# **********
# running_loss:-------
# 0.007115646504345032
# epoch 297
# **********
# running_loss:-------
# 0.007097568549519156
# epoch 298
# **********
# running_loss:-------
# 0.007079184856015509
# epoch 299
# **********
# running_loss:-------
# 0.007060487757344785
# epoch 300
# **********
# running_loss:-------
# 0.007041475352135726
# epoch 301
# **********
# running_loss:-------
# 0.007022141118072988
# epoch 302
# **********
# running_loss:-------
# 0.00700248157983215
# epoch 303
# **********
# running_loss:-------
# 0.0069824923105736595
# epoch 304
# **********
# running_loss:-------
# 0.0069621689770737035
# epoch 305
# **********
# running_loss:-------
# 0.00694150667919998
# epoch 306
# **********
# running_loss:-------
# 0.006920499778820046
# epoch 307
# **********
# running_loss:-------
# 0.006899143782567918
# epoch 308
# **********
# running_loss:-------
# 0.006877434932399641
# epoch 309
# **********
# running_loss:-------
# 0.006855369699452071
# epoch 310
# **********
# running_loss:-------
# 0.006832942692122115
# epoch 311
# **********
# running_loss:-------
# 0.006810149456646804
# epoch 312
# **********
# running_loss:-------
# 0.006786985713412154
# epoch 313
# **********
# running_loss:-------
# 0.006763448028734973
# epoch 314
# **********
# running_loss:-------
# 0.006739532086076382
# epoch 315
# **********
# running_loss:-------
# 0.006715231786761888
# epoch 316
# **********
# running_loss:-------
# 0.0066905438490265055
# epoch 317
# **********
# running_loss:-------
# 0.006665464023047382
# epoch 318
# **********
# running_loss:-------
# 0.0066399877122205195
# epoch 319
# **********
# running_loss:-------
# 0.0066141111622939905
# epoch 320
# **********
# running_loss:-------
# 0.006587831866972949
# epoch 321
# **********
# running_loss:-------
# 0.006561144014829178
# epoch 322
# **********
# running_loss:-------
# 0.006534043428230597
# epoch 323
# **********
# running_loss:-------
# 0.006506526377905275
# epoch 324
# **********
# running_loss:-------
# 0.006478588733005304
# epoch 325
# **********
# running_loss:-------
# 0.006450226867828573
# epoch 326
# **********
# running_loss:-------
# 0.006421435497138431
# epoch 327
# **********
# running_loss:-------
# 0.006392209486905425
# epoch 328
# **********
# running_loss:-------
# 0.006362546930449456
# epoch 329
# **********
# running_loss:-------
# 0.006332441573670204
# epoch 330
# **********
# running_loss:-------
# 0.006301890752002967
# epoch 331
# **********
# running_loss:-------
# 0.006270888703884724
# epoch 332
# **********
# running_loss:-------
# 0.0062394319746813184
# epoch 333
# **********
# running_loss:-------
# 0.006207515265741795
# epoch 334
# **********
# running_loss:-------
# 0.006175133566988681
# epoch 335
# **********
# running_loss:-------
# 0.006142283272959826
# epoch 336
# **********
# running_loss:-------
# 0.006108955586524772
# epoch 337
# **********
# running_loss:-------
# 0.00607514818686634
# epoch 338
# **********
# running_loss:-------
# 0.006040853521398326
# epoch 339
# **********
# running_loss:-------
# 0.006006067572844121
# epoch 340
# **********
# running_loss:-------
# 0.005970782892139938
# epoch 341
# **********
# running_loss:-------
# 0.005934991614994705
# epoch 342
# **********
# running_loss:-------
# 0.005898688076873968
# epoch 343
# **********
# running_loss:-------
# 0.005861864046038945
# epoch 344
# **********
# running_loss:-------
# 0.005824512771822979
# epoch 345
# **********
# running_loss:-------
# 0.005786624806952065
# epoch 346
# **********
# running_loss:-------
# 0.005748193127448983
# epoch 347
# **********
# running_loss:-------
# 0.005709206891236281
# epoch 348
# **********
# running_loss:-------
# 0.005669656901313933
# epoch 349
# **********
# running_loss:-------
# 0.0056295335358797485
# epoch 350
# **********
# running_loss:-------
# 0.005588827505028968
# epoch 351
# **********
# running_loss:-------
# 0.005547526624684711
# epoch 352
# **********
# running_loss:-------
# 0.005505618788885917
# epoch 353
# **********
# running_loss:-------
# 0.005463093366012802
# epoch 354
# **********
# running_loss:-------
# 0.005419937483545435
# epoch 355
# **********
# running_loss:-------
# 0.0053761383029025545
# epoch 356
# **********
# running_loss:-------
# 0.005331682961518309
# epoch 357
# **********
# running_loss:-------
# 0.005286555727492526
# epoch 358
# **********
# running_loss:-------
# 0.005240746671584183
# epoch 359
# **********
# running_loss:-------
# 0.005194238896412678
# epoch 360
# **********
# running_loss:-------
# 0.005147018277708969
# epoch 361
# **********
# running_loss:-------
# 0.005099071677416223
# epoch 362
# **********
# running_loss:-------
# 0.005050384384543553
# epoch 363
# **********
# running_loss:-------
# 0.005000941710567848
# epoch 364
# **********
# running_loss:-------
# 0.00495073202836664
# epoch 365
# **********
# running_loss:-------
# 0.004899742095791871
# epoch 366
# **********
# running_loss:-------
# 0.004847959436116746
# epoch 367
# **********
# running_loss:-------
# 0.00479537525410682
# epoch 368
# **********
# running_loss:-------
# 0.004741976712034039
# epoch 369
# **********
# running_loss:-------
# 0.004687753682144605
# epoch 370
# **********
# running_loss:-------
# 0.004632701475593392
# epoch 371
# **********
# running_loss:-------
# 0.004576810549547235
# epoch 372
# **********
# running_loss:-------
# 0.0045200788314721215
# epoch 373
# **********
# running_loss:-------
# 0.004462506130060139
# epoch 374
# **********
# running_loss:-------
# 0.004404090729986503
# epoch 375
# **********
# running_loss:-------
# 0.004344840125060953
# epoch 376
# **********
# running_loss:-------
# 0.004284758146181824
# epoch 377
# **********
# running_loss:-------
# 0.004223856637754905
# epoch 378
# **********
# running_loss:-------
# 0.004162149552365079
# epoch 379
# **********
# running_loss:-------
# 0.0040996583515750884
# epoch 380
# **********
# running_loss:-------
# 0.004036401934862586
# epoch 381
# **********
# running_loss:-------
# 0.0039724132796167015
# epoch 382
# **********
# running_loss:-------
# 0.0039077180736176425
# epoch 383
# **********
# running_loss:-------
# 0.003842359390344883
# epoch 384
# **********
# running_loss:-------
# 0.0037763785483264016
# epoch 385
# **********
# running_loss:-------
# 0.003709826664316562
# epoch 386
# **********
# running_loss:-------
# 0.0036427565235629413
# epoch 387
# **********
# running_loss:-------
# 0.0035752271973612908
# epoch 388
# **********
# running_loss:-------
# 0.0035073076875755983
# epoch 389
# **********
# running_loss:-------
# 0.0034390715671724454
# epoch 390
# **********
# running_loss:-------
# 0.0033705955307175334
# epoch 391
# **********
# running_loss:-------
# 0.003301962461559169
# epoch 392
# **********
# running_loss:-------
# 0.003233269952993737
# epoch 393
# **********
# running_loss:-------
# 0.0031646063762902
# epoch 394
# **********
# running_loss:-------
# 0.0030960743089892117
# epoch 395
# **********
# running_loss:-------
# 0.003027775423663459
# epoch 396
# **********
# running_loss:-------
# 0.0029598204632318528
# epoch 397
# **********
# running_loss:-------
# 0.002892323142806438
# epoch 398
# **********
# running_loss:-------
# 0.002825391583117362
# epoch 399
# **********
# running_loss:-------
# 0.002759145283354871
# epoch 400
# **********
# running_loss:-------
# 0.0026936932738623144
# epoch 401
# **********
# running_loss:-------
# 0.0026291540439175413
# epoch 402
# **********
# running_loss:-------
# 0.0025656390553135547
# epoch 403
# **********
# running_loss:-------
# 0.0025032560691064533
# epoch 404
# **********
# running_loss:-------
# 0.0024421098786148363
# epoch 405
# **********
# running_loss:-------
# 0.0023823031646173737
# epoch 406
# **********
# running_loss:-------
# 0.002323926898672819
# epoch 407
# **********
# running_loss:-------
# 0.0022670707654197327
# epoch 408
# **********
# running_loss:-------
# 0.0022118177389307404
# epoch 409
# **********
# running_loss:-------
# 0.0021582323308322725
# epoch 410
# **********
# running_loss:-------
# 0.0021063754997134258
# epoch 411
# **********
# running_loss:-------
# 0.002056295511669992
# epoch 412
# **********
# running_loss:-------
# 0.0020080353094512103
# epoch 413
# **********
# running_loss:-------
# 0.0019616233089184906
# epoch 414
# **********
# running_loss:-------
# 0.0019170785298516385
# epoch 415
# **********
# running_loss:-------
# 0.0018744045847280601
# epoch 416
# **********
# running_loss:-------
# 0.0018335965517771822
# epoch 417
# **********
# running_loss:-------
# 0.001794646146645806
# epoch 418
# **********
# running_loss:-------
# 0.0017575254023540765
# epoch 419
# **********
# running_loss:-------
# 0.0017222037256569434
# epoch 420
# **********
# running_loss:-------
# 0.001688640661850869
# epoch 421
# **********
# running_loss:-------
# 0.00165678918360147
# epoch 422
# **********
# running_loss:-------
# 0.0016265942275991317
# epoch 423
# **********
# running_loss:-------
# 0.0015979973112607636
# epoch 424
# **********
# running_loss:-------
# 0.00157093686614404
# epoch 425
# **********
# running_loss:-------
# 0.0015453457557793452
# epoch 426
# **********
# running_loss:-------
# 0.0015211545071429618
# epoch 427
# **********
# running_loss:-------
# 0.0014982927593073416
# epoch 428
# **********
# running_loss:-------
# 0.0014766876114432241
# epoch 429
# **********
# running_loss:-------
# 0.0014562693005313958
# epoch 430
# **********
# running_loss:-------
# 0.0014369654915134759
# epoch 431
# **********
# running_loss:-------
# 0.0014187073901391221
# epoch 432
# **********
# running_loss:-------
# 0.0014014287133350763
# epoch 433
# **********
# running_loss:-------
# 0.0013850622121032315
# epoch 434
# **********
# running_loss:-------
# 0.0013695451397227323
# epoch 435
# **********
# running_loss:-------
# 0.0013548179952608246
# epoch 436
# **********
# running_loss:-------
# 0.0013408241627611984
# epoch 437
# **********
# running_loss:-------
# 0.0013275099261277068
# epoch 438
# **********
# running_loss:-------
# 0.0013148224512903864
# epoch 439
# **********
# running_loss:-------
# 0.001302718035008376
# epoch 440
# **********
# running_loss:-------
# 0.001291151889141024
# epoch 441
# **********
# running_loss:-------
# 0.001280081806308514
# epoch 442
# **********
# running_loss:-------
# 0.001269471123458132
# epoch 443
# **********
# running_loss:-------
# 0.0012592851903467023
# epoch 444
# **********
# running_loss:-------
# 0.0012494904341889812
# epoch 445
# **********
# running_loss:-------
# 0.0012400593194433302
# epoch 446
# **********
# running_loss:-------
# 0.0012309642575270912
# epoch 447
# **********
# running_loss:-------
# 0.001222180490276218
# epoch 448
# **********
# running_loss:-------
# 0.0012136864116042245
# epoch 449
# **********
# running_loss:-------
# 0.0012054611451060022
# epoch 450
# **********
# running_loss:-------
# 0.0011974858172793027
# epoch 451
# **********
# running_loss:-------
# 0.0011897446294368247
# epoch 452
# **********
# running_loss:-------
# 0.001182222894998874
# epoch 453
# **********
# running_loss:-------
# 0.0011749060322353859
# epoch 454
# **********
# running_loss:-------
# 0.001167781397048839
# epoch 455
# **********
# running_loss:-------
# 0.0011608399663037843
# epoch 456
# **********
# running_loss:-------
# 0.0011540704836434889
# epoch 457
# **********
# running_loss:-------
# 0.0011474624525866371
# epoch 458
# **********
# running_loss:-------
# 0.001141008718046572
# epoch 459
# **********
# running_loss:-------
# 0.0011347017739842577
# epoch 460
# **********
# running_loss:-------
# 0.001128535725831218
# epoch 461
# **********
# running_loss:-------
# 0.0011225016563444425
# epoch 462
# **********
# running_loss:-------
# 0.0011165957284161475
# epoch 463
# **********
# running_loss:-------
# 0.00111081293945812
# epoch 464
# **********
# running_loss:-------
# 0.0011051485397631502
# epoch 465
# **********
# running_loss:-------
# 0.0010995974745078116
# epoch 466
# **********
# running_loss:-------
# 0.0010941552746899165
# epoch 467
# **********
# running_loss:-------
# 0.0010888188123112962
# epoch 468
# **********
# running_loss:-------
# 0.0010835842628252666
# epoch 469
# **********
# running_loss:-------
# 0.0010784490741008184
# epoch 470
# **********
# running_loss:-------
# 0.001073410089130753
# epoch 471
# **********
# running_loss:-------
# 0.0010684648659425341
# epoch 472
# **********
# running_loss:-------
# 0.0010636090959368443
# epoch 473
# **********
# running_loss:-------
# 0.0010588412013921905
# epoch 474
# **********
# running_loss:-------
# 0.0010541592916024011
# epoch 475
# **********
# running_loss:-------
# 0.0010495597308164868
# epoch 476
# **********
# running_loss:-------
# 0.001045041777645177
# epoch 477
# **********
# running_loss:-------
# 0.0010406029963727847
# epoch 478
# **********
# running_loss:-------
# 0.0010362411352444793
# epoch 479
# **********
# running_loss:-------
# 0.0010319539413678213
# epoch 480
# **********
# running_loss:-------
# 0.0010277409917892621
# epoch 481
# **********
# running_loss:-------
# 0.0010235991751007638
# epoch 482
# **********
# running_loss:-------
# 0.0010195271662248341
# epoch 483
# **********
# running_loss:-------
# 0.0010155231283969285
# epoch 484
# **********
# running_loss:-------
# 0.0010115861819608816
# epoch 485
# **********
# running_loss:-------
# 0.0010077149659571169
# epoch 486
# **********
# running_loss:-------
# 0.0010039074005993654
# epoch 487
# **********
# running_loss:-------
# 0.0010001625032304462
# epoch 488
# **********
# running_loss:-------
# 0.0009964782116022295
# epoch 489
# **********
# running_loss:-------
# 0.000992853574341782
# epoch 490
# **********
# running_loss:-------
# 0.0009892870304599429
# epoch 491
# **********
# running_loss:-------
# 0.000985777922845309
# epoch 492
# **********
# running_loss:-------
# 0.0009823241209932102
# epoch 493
# **********
# running_loss:-------
# 0.0009789251549763252
# epoch 494
# **********
# running_loss:-------
# 0.0009755795938721236
# epoch 495
# **********
# running_loss:-------
# 0.0009722861493858039
# epoch 496
# **********
# running_loss:-------
# 0.0009690443695073869
# epoch 497
# **********
# running_loss:-------
# 0.0009658525207577462
# epoch 498
# **********
# running_loss:-------
# 0.0009627106964682207
# epoch 499
# **********
# running_loss:-------
# 0.0009596166413763526
# epoch 500
# **********
# running_loss:-------
# 0.000956570020361488
# epoch 501
# **********
# running_loss:-------
# 0.0009535690955836659
# epoch 502
# **********
# running_loss:-------
# 0.0009506130996782102
# epoch 503
# **********
# running_loss:-------
# 0.0009477016871437849
# epoch 504
# **********
# running_loss:-------
# 0.000944833829866249
# epoch 505
# **********
# running_loss:-------
# 0.0009420087652209637
# epoch 506
# **********
# running_loss:-------
# 0.0009392254178356137
# epoch 507
# **********
# running_loss:-------
# 0.0009364832800995795
# epoch 508
# **********
# running_loss:-------
# 0.0009337806832826475
# epoch 509
# **********
# running_loss:-------
# 0.0009311174223781942
# epoch 510
# **********
# running_loss:-------
# 0.0009284922463481135
# epoch 511
# **********
# running_loss:-------
# 0.0009259052225009383
# epoch 512
# **********
# running_loss:-------
# 0.0009233548355414699
# epoch 513
# **********
# running_loss:-------
# 0.0009208410969879994
# epoch 514
# **********
# running_loss:-------
# 0.000918363107939809
# epoch 515
# **********
# running_loss:-------
# 0.0009159196046080913
# epoch 516
# **********
# running_loss:-------
# 0.0009135103692829227
# epoch 517
# **********
# running_loss:-------
# 0.0009111351943506589
# epoch 518
# **********
# running_loss:-------
# 0.0009087925839502553
# epoch 519
# **********
# running_loss:-------
# 0.0009064828768995945
# epoch 520
# **********
# running_loss:-------
# 0.000904204742907143
# epoch 521
# **********
# running_loss:-------
# 0.0009019579569633188
# epoch 522
# **********
# running_loss:-------
# 0.0008997415703970101
# epoch 523
# **********
# running_loss:-------
# 0.00089755544721654
# epoch 524
# **********
# running_loss:-------
# 0.0008953988378797733
# epoch 525
# **********
# running_loss:-------
# 0.0008932711899353355
# epoch 526
# **********
# running_loss:-------
# 0.0008911722157103485
# epoch 527
# **********
# running_loss:-------
# 0.0008891007268774029
# epoch 528
# **********
# running_loss:-------
# 0.0008870564670952686
# epoch 529
# **********
# running_loss:-------
# 0.0008850393939880102
# epoch 530
# **********
# running_loss:-------
# 0.0008830491717713687
# epoch 531
# **********
# running_loss:-------
# 0.0008810849590412817
# epoch 532
# **********
# running_loss:-------
# 0.0008791465511703287
# epoch 533
# **********
# running_loss:-------
# 0.0008772333631430774
# epoch 534
# **********
# running_loss:-------
# 0.0008753448819926658
# epoch 535
# **********
# running_loss:-------
# 0.0008734807957772238
# epoch 536
# **********
# running_loss:-------
# 0.0008716408337458077
# epoch 537
# **********
# running_loss:-------
# 0.0008698242683500561
# epoch 538
# **********
# running_loss:-------
# 0.0008680307267860173
# epoch 539
# **********
# running_loss:-------
# 0.0008662601663933533
# epoch 540
# **********
# running_loss:-------
# 0.0008645113239520615
# epoch 541
# **********
# running_loss:-------
# 0.0008627847915876305
# epoch 542
# **********
# running_loss:-------
# 0.0008610801086632128
# epoch 543
# **********
# running_loss:-------
# 0.0008593967312595015
# epoch 544
# **********
# running_loss:-------
# 0.0008577342712622233
# epoch 545
# **********
# running_loss:-------
# 0.0008560923633566855
# epoch 546
# **********
# running_loss:-------
# 0.0008544709854069126
# epoch 547
# **********
# running_loss:-------
# 0.0008528693634595765
# epoch 548
# **********
# running_loss:-------
# 0.0008512877507274819
# epoch 549
# **********
# running_loss:-------
# 0.0008497253907954393
# epoch 550
# **********
# running_loss:-------
# 0.0008481822327080453
# epoch 551
# **********
# running_loss:-------
# 0.0008466577918912626
# epoch 552
# **********
# running_loss:-------
# 0.0008451519104070409
# epoch 553
# **********
# running_loss:-------
# 0.0008436642337005725
# epoch 554
# **********
# running_loss:-------
# 0.0008421947040382002
# epoch 555
# **********
# running_loss:-------
# 0.0008407426073332696
# epoch 556
# **********
# running_loss:-------
# 0.0008393081058372656
# epoch 557
# **********
# running_loss:-------
# 0.0008378907254042334
# epoch 558
# **********
# running_loss:-------
# 0.0008364902336301331
# epoch 559
# **********
# running_loss:-------
# 0.0008351062733057359
# epoch 560
# **********
# running_loss:-------
# 0.0008337388850531635
# epoch 561
# **********
# running_loss:-------
# 0.0008323876719890733
# epoch 562
# **********
# running_loss:-------
# 0.0008310526598044686
# epoch 563
# **********
# running_loss:-------
# 0.0008297334248347948
# epoch 564
# **********
# running_loss:-------
# 0.0008284293886058712
# epoch 565
# **********
# running_loss:-------
# 0.0008271409677195966
# epoch 566
# **********
# running_loss:-------
# 0.0008258673034707715
# epoch 567
# **********
# running_loss:-------
# 0.000824608571667388
# epoch 568
# **********
# running_loss:-------
# 0.0008233644127301987
# epoch 569
# **********
# running_loss:-------
# 0.0008221346708541699
# epoch 570
# **********
# running_loss:-------
# 0.0008209193387870443
# epoch 571
# **********
# running_loss:-------
# 0.0008197179001491328
# epoch 572
# **********
# running_loss:-------
# 0.0008185302707336688
# epoch 573
# **********
# running_loss:-------
# 0.0008173565394400561
# epoch 574
# **********
# running_loss:-------
# 0.0008161964035220975
# epoch 575
# **********
# running_loss:-------
# 0.0008150492919000709
# epoch 576
# **********
# running_loss:-------
# 0.0008139154703478808
# epoch 577
# **********
# running_loss:-------
# 0.000812794411086048
# epoch 578
# **********
# running_loss:-------
# 0.0008116862938330958
# epoch 579
# **********
# running_loss:-------
# 0.0008105907834446701
# epoch 580
# **********
# running_loss:-------
# 0.0008095077835795081
# epoch 581
# **********
# running_loss:-------
# 0.0008084368776357111
# epoch 582
# **********
# running_loss:-------
# 0.0008073781656991715
# epoch 583
# **********
# running_loss:-------
# 0.000806331566904849
# epoch 584
# **********
# running_loss:-------
# 0.0008052969210157748
# epoch 585
# **********
# running_loss:-------
# 0.0008042737384571721
# epoch 586
# **********
# running_loss:-------
# 0.0008032617498764082
# epoch 587
# **********
# running_loss:-------
# 0.0008022613926604466
# epoch 588
# **********
# running_loss:-------
# 0.0008012721346926736
# epoch 589
# **********
# running_loss:-------
# 0.0008002940496095723
# epoch 590
# **********
# running_loss:-------
# 0.0007993269779088798
# epoch 591
# **********
# running_loss:-------
# 0.0007983706933012041
# epoch 592
# **********
# running_loss:-------
# 0.0007974246090883995
# epoch 593
# **********
# running_loss:-------
# 0.0007964892365546148
# epoch 594
# **********
# running_loss:-------
# 0.0007955645125625497
# epoch 595
# **********
# running_loss:-------
# 0.0007946498386587656
# epoch 596
# **********
# running_loss:-------
# 0.0007937454156075523
# epoch 597
# **********
# running_loss:-------
# 0.0007928509383163937
# epoch 598
# **********
# running_loss:-------
# 0.0007919662380873542
# epoch 599
# **********
# running_loss:-------
# 0.0007910912519964353
# epoch 600
# **********
# running_loss:-------
# 0.0007902261564204339
# epoch 601
# **********
# running_loss:-------
# 0.0007893705500440721
# epoch 602
# **********
# running_loss:-------
# 0.0007885240432125644
# epoch 603
# **********
# running_loss:-------
# 0.0007876869932299401
# epoch 604
# **********
# running_loss:-------
# 0.0007868590912353536
# epoch 605
# **********
# running_loss:-------
# 0.000786040249751412
# epoch 606
# **********
# running_loss:-------
# 0.0007852304703897284
# epoch 607
# **********
# running_loss:-------
# 0.0007844295019520134
# epoch 608
# **********
# running_loss:-------
# 0.0007836370458396027
# epoch 609
# **********
# running_loss:-------
# 0.0007828533527293813
# epoch 610
# **********
# running_loss:-------
# 0.0007820781676547301
# epoch 611
# **********
# running_loss:-------
# 0.0007813113441958899
# epoch 612
# **********
# running_loss:-------
# 0.000780552821419678
# epoch 613
# **********
# running_loss:-------
# 0.0007798026196371555
# epoch 614
# **********
# running_loss:-------
# 0.0007790607946385639
# epoch 615
# **********
# running_loss:-------
# 0.0007783266358211764
# epoch 616
# **********
# running_loss:-------
# 0.0007776006106711949
# epoch 617
# **********
# running_loss:-------
# 0.000776882425306292
# epoch 618
# **********
# running_loss:-------
# 0.000776172071502503
# epoch 619
# **********
# running_loss:-------
# 0.0007754691820017196
# epoch 620
# **********
# running_loss:-------
# 0.0007747739238665645
# epoch 621
# **********
# running_loss:-------
# 0.0007740863444263128
# epoch 622
# **********
# running_loss:-------
# 0.0007734060676774869
# epoch 623
# **********
# running_loss:-------
# 0.00077273305107825
# epoch 624
# **********
# running_loss:-------
# 0.0007720671408380843
# epoch 625
# **********
# running_loss:-------
# 0.0007714085622509739
# epoch 626
# **********
# running_loss:-------
# 0.0007707568973878092
# epoch 627
# **********
# running_loss:-------
# 0.0007701121935541651
# epoch 628
# **********
# running_loss:-------
# 0.0007694743665432746
# epoch 629
# **********
# running_loss:-------
# 0.0007688432913129476
# epoch 630
# **********
# running_loss:-------
# 0.0007682190022995568
# epoch 631
# **********
# running_loss:-------
# 0.0007676014551126507
# epoch 632
# **********
# running_loss:-------
# 0.0007669903557751015
# epoch 633
# **********
# running_loss:-------
# 0.0007663858629833658
# epoch 634
# **********
# running_loss:-------
# 0.0007657878593267139
# epoch 635
# **********
# running_loss:-------
# 0.0007651961605124864
# epoch 636
# **********
# running_loss:-------
# 0.0007646106258800697
# epoch 637
# **********
# running_loss:-------
# 0.0007640315194258539
# epoch 638
# **********
# running_loss:-------
# 0.000763458456448393
# epoch 639
# **********
# running_loss:-------
# 0.0007628915221024614
# epoch 640
# **********
# running_loss:-------
# 0.0007623306073671956
# epoch 641
# **********
# running_loss:-------
# 0.0007617755579306738
# epoch 642
# **********
# running_loss:-------
# 0.0007612263311799585
# epoch 643
# **********
# running_loss:-------
# 0.0007606829381830375
# epoch 644
# **********
# running_loss:-------
# 0.0007601452889976983
# epoch 645
# **********
# running_loss:-------
# 0.0007596133481684606
# epoch 646
# **********
# running_loss:-------
# 0.0007590870837474709
# epoch 647
# **********
# running_loss:-------
# 0.0007585661805459338
# epoch 648
# **********
# running_loss:-------
# 0.0007580507550976718
# epoch 649
# **********
# running_loss:-------
# 0.0007575407541009631
# epoch 650
# **********
# running_loss:-------
# 0.0007570360557131426
# epoch 651
# **********
# running_loss:-------
# 0.0007565367543557583
# epoch 652
# **********
# running_loss:-------
# 0.0007560426484350136
# epoch 653
# **********
# running_loss:-------
# 0.0007555536526776335
# epoch 654
# **********
# running_loss:-------
# 0.0007550699599320448
# epoch 655
# **********
# running_loss:-------
# 0.0007545912539192433
# epoch 656
# **********
# running_loss:-------
# 0.0007541175109864415
# epoch 657
# **********
# running_loss:-------
# 0.0007536489277266963
# epoch 658
# **********
# running_loss:-------
# 0.000753185104720745
# epoch 659
# **********
# running_loss:-------
# 0.000752726038271358
# epoch 660
# **********
# running_loss:-------
# 0.0007522718728548795
# epoch 661
# **********
# running_loss:-------
# 0.0007518224310991051
# epoch 662
# **********
# running_loss:-------
# 0.0007513775816101942
# epoch 663
# **********
# running_loss:-------
# 0.0007509373164485839
# epoch 664
# **********
# running_loss:-------
# 0.0007505017815126298
# epoch 665
# **********
# running_loss:-------
# 0.0007500706500952445
# epoch 666
# **********
# running_loss:-------
# 0.0007496439748345449
# epoch 667
# **********
# running_loss:-------
# 0.0007492219122465706
# epoch 668
# **********
# running_loss:-------
# 0.0007488040591200286
# epoch 669
# **********
# running_loss:-------
# 0.0007483905760710907
# epoch 670
# **********
# running_loss:-------
# 0.0007479812810112152
# epoch 671
# **********
# running_loss:-------
# 0.0007475762878198037
# epoch 672
# **********
# running_loss:-------
# 0.0007471754087202694
# epoch 673
# **********
# running_loss:-------
# 0.0007467786716314333
# epoch 674
# **********
# running_loss:-------
# 0.0007463862036811021
# epoch 675
# **********
# running_loss:-------
# 0.0007459976838265337
# epoch 676
# **********
# running_loss:-------
# 0.0007456131531638534
# epoch 677
# **********
# running_loss:-------
# 0.0007452325153517983
# epoch 678
# **********
# running_loss:-------
# 0.0007448559493741858
# epoch 679
# **********
# running_loss:-------
# 0.0007444831558976456
# epoch 680
# **********
# running_loss:-------
# 0.0007441140792741371
# epoch 681
# **********
# running_loss:-------
# 0.0007437488445458503
# epoch 682
# **********
# running_loss:-------
# 0.0007433873477637622
# epoch 683
# **********
# running_loss:-------
# 0.000743029492847312
# epoch 684
# **********
# running_loss:-------
# 0.0007426753405400807
# epoch 685
# **********
# running_loss:-------
# 0.0007423248673314821
# epoch 686
# **********
# running_loss:-------
# 0.0007419778693525018
# epoch 687
# **********
# running_loss:-------
# 0.0007416344970519312
# epoch 688
# **********
# running_loss:-------
# 0.0007412945746691785
# epoch 689
# **********
# running_loss:-------
# 0.0007409582548808528
# epoch 690
# **********
# running_loss:-------
# 0.0007406252532136014
# epoch 691
# **********
# running_loss:-------
# 0.000740295611427155
# epoch 692
# **********
# running_loss:-------
# 0.0007399693220796545
# epoch 693
# **********
# running_loss:-------
# 0.0007396463850762996
# epoch 694
# **********
# running_loss:-------
# 0.0007393266616050906
# epoch 695
# **********
# running_loss:-------
# 0.0007390101610750024
# epoch 696
# **********
# running_loss:-------
# 0.0007386970439837056
# epoch 697
# **********
# running_loss:-------
# 0.0007383869383804552
# epoch 698
# **********
# running_loss:-------
# 0.000738079950844995
# epoch 699
# **********
# running_loss:-------
# 0.0007377760939621245
# epoch 700
# **********
# running_loss:-------
# 0.000737475255724757
# epoch 701
# **********
# running_loss:-------
# 0.0007371773428963543
# epoch 702
# **********
# running_loss:-------
# 0.0007368826192600049
# epoch 703
# **********
# running_loss:-------
# 0.0007365907523257761
# epoch 704
# **********
# running_loss:-------
# 0.0007363017979550103
# epoch 705
# **********
# running_loss:-------
# 0.0007360157347227377
# epoch 706
# **********
# running_loss:-------
# 0.0007357326103374362
# epoch 707
# **********
# running_loss:-------
# 0.0007354522606516059
# epoch 708
# **********
# running_loss:-------
# 0.0007351748100438319
# epoch 709
# **********
# running_loss:-------
# 0.0007348999584460379
# epoch 710
# **********
# running_loss:-------
# 0.0007346279875112543
# epoch 711
# **********
# running_loss:-------
# 0.0007343586099221058
# epoch 712
# **********
# running_loss:-------
# 0.0007340920080515368
# epoch 713
# **********
# running_loss:-------
# 0.0007338281024802182
# epoch 714
# **********
# running_loss:-------
# 0.0007335668120113071
# epoch 715
# **********
# running_loss:-------
# 0.0007333079442940804
# epoch 716
# **********
# running_loss:-------
# 0.0007330518415118477
# epoch 717
# **********
# running_loss:-------
# 0.0007327981414309405
# epoch 718
# **********
# running_loss:-------
# 0.0007325469361976888
# epoch 719
# **********
# running_loss:-------
# 0.0007322983130998834
# epoch 720
# **********
# running_loss:-------
# 0.0007320520953578247
# epoch 721
# **********
# running_loss:-------
# 0.0007318082472553297
# epoch 722
# **********
# running_loss:-------
# 0.0007315668060490937
# epoch 723
# **********
# running_loss:-------
# 0.0007313276821998075
# epoch 724
# **********
# running_loss:-------
# 0.0007310909943506106
# epoch 725
# **********
# running_loss:-------
# 0.0007308566856921532
# epoch 726
# **********
# running_loss:-------
# 0.0007306245894462146
# epoch 727
# **********
# running_loss:-------
# 0.0007303947191930024
# epoch 728
# **********
# running_loss:-------
# 0.0007301671552050523
# epoch 729
# **********
# running_loss:-------
# 0.0007299417203708616
# epoch 730
# **********
# running_loss:-------
# 0.0007297185379551065
# epoch 731
# **********
# running_loss:-------
# 0.0007294975266424433
# epoch 732
# **********
# running_loss:-------
# 0.0007292785697568478
# epoch 733
# **********
# running_loss:-------
# 0.0007290618596964437
# epoch 734
# **********
# running_loss:-------
# 0.0007288471211124506
# epoch 735
# **********
# running_loss:-------
# 0.0007286345891818307
# epoch 736
# **********
# running_loss:-------
# 0.0007284240430425352
# epoch 737
# **********
# running_loss:-------
# 0.0007282155371575953
# epoch 738
# **********
# running_loss:-------
# 0.0007280090598665187
# epoch 739
# **********
# running_loss:-------
# 0.0007278046685000593
# epoch 740
# **********
# running_loss:-------
# 0.0007276021553260724
# epoch 741
# **********
# running_loss:-------
# 0.0007274015335455621
# epoch 742
# **********
# running_loss:-------
# 0.0007272027966646775
# epoch 743
# **********
# running_loss:-------
# 0.0007270060336539227
# epoch 744
# **********
# running_loss:-------
# 0.0007268111176224932
# epoch 745
# **********
# running_loss:-------
# 0.0007266181118498899
# epoch 746
# **********
# running_loss:-------
# 0.0007264269046608286
# epoch 747
# **********
# running_loss:-------
# 0.0007262375212012083
# epoch 748
# **********
# running_loss:-------
# 0.0007260499470850152
# epoch 749
# **********
# running_loss:-------
# 0.0007258642081928542
# epoch 750
# **********
# running_loss:-------
# 0.0007256801800513398
# epoch 751
# **********
# running_loss:-------
# 0.0007254978673531088
# epoch 752
# **********
# running_loss:-------
# 0.0007253172445730595
# epoch 753
# **********
# running_loss:-------
# 0.0007251383871488889
# epoch 754
# **********
# running_loss:-------
# 0.0007249611613641384
# epoch 755
# **********
# running_loss:-------
# 0.0007247855926017088
# epoch 756
# **********
# running_loss:-------
# 0.0007246117049409911
# epoch 757
# **********
# running_loss:-------
# 0.000724439433846374
# epoch 758
# **********
# running_loss:-------
# 0.0007242686622863307
# epoch 759
# **********
# running_loss:-------
# 0.0007240995560673745
# epoch 760
# **********
# running_loss:-------
# 0.0007239320015945056
# epoch 761
# **********
# running_loss:-------
# 0.0007237660552267705
# epoch 762
# **********
# running_loss:-------
# 0.0007236016862250255
# epoch 763
# **********
# running_loss:-------
# 0.0007234387945507787
# epoch 764
# **********
# running_loss:-------
# 0.0007232773868874829
# epoch 765
# **********
# running_loss:-------
# 0.0007231174557221786
# epoch 766
# **********
# running_loss:-------
# 0.0007229590859726384
# epoch 767
# **********
# running_loss:-------
# 0.000722802076068766
# epoch 768
# **********
# running_loss:-------
# 0.0007226465712216112
# epoch 769
# **********
# running_loss:-------
# 0.0007224923842944924
# epoch 770
# **********
# running_loss:-------
# 0.0007223396658784018
# epoch 771
# **********
# running_loss:-------
# 0.0007221883537366468
# epoch 772
# **********
# running_loss:-------
# 0.0007220384608095297
# epoch 773
# **********
# running_loss:-------
# 0.0007218899032931869
# epoch 774
# **********
# running_loss:-------
# 0.0007217426743145641
# epoch 775
# **********
# running_loss:-------
# 0.0007215967776419911
# epoch 776
# **********
# running_loss:-------
# 0.0007214521910446917
# epoch 777
# **********
# running_loss:-------
# 0.000721308913479858
# epoch 778
# **********
# running_loss:-------
# 0.0007211669675337685
# epoch 779
# **********
# running_loss:-------
# 0.0007210263172295385
# epoch 780
# **********
# running_loss:-------
# 0.0007208869369235648
# epoch 781
# **********
# running_loss:-------
# 0.0007207487246339401
# epoch 782
# **********
# running_loss:-------
# 0.0007206117896896299
# epoch 783
# **********
# running_loss:-------
# 0.0007204760907101066
# epoch 784
# **********
# running_loss:-------
# 0.0007203415774746726
# epoch 785
# **********
# running_loss:-------
# 0.0007202082704365896
# epoch 786
# **********
# running_loss:-------
# 0.0007200760669740454
# epoch 787
# **********
# running_loss:-------
# 0.0007199451088378622
# epoch 788
# **********
# running_loss:-------
# 0.000719815272147159
# epoch 789
# **********
# running_loss:-------
# 0.000719686569534136
# epoch 790
# **********
# running_loss:-------
# 0.0007195590824563381
# epoch 791
# **********
# running_loss:-------
# 0.0007194326276639143
# epoch 792
# **********
# running_loss:-------
# 0.0007193073282319391
# epoch 793
# **********
# running_loss:-------
# 0.0007191831044329812
# epoch 794
# **********
# running_loss:-------
# 0.000719059923086778
# epoch 795
# **********
# running_loss:-------
# 0.0007189379514929541
# epoch 796
# **********
# running_loss:-------
# 0.0007188169881999144
# epoch 797
# **********
# running_loss:-------
# 0.0007186970585194593
# epoch 798
# **********
# running_loss:-------
# 0.0007185781719316638
# epoch 799
# **********
# running_loss:-------
# 0.0007184602818182588
# epoch 800
# **********
# running_loss:-------
# 0.0007183434624793327
# epoch 801
# **********
# running_loss:-------
# 0.0007182275860049725
# epoch 802
# **********
# running_loss:-------
# 0.0007181127364597441
# epoch 803
# **********
# running_loss:-------
# 0.0007179989095776136
# epoch 804
# **********
# running_loss:-------
# 0.0007178860171227822
# epoch 805
# **********
# running_loss:-------
# 0.0007177740272421979
# epoch 806
# **********
# running_loss:-------
# 0.0007176630123399338
# epoch 807
# **********
# running_loss:-------
# 0.000717552980758456
# epoch 808
# **********
# running_loss:-------
# 0.0007174438982983939
# epoch 809
# **********
# running_loss:-------
# 0.0007173357330355945
# epoch 810
# **********
# running_loss:-------
# 0.0007172285142160894
# epoch 811
# **********
# running_loss:-------
# 0.0007171221119628503
# epoch 812
# **********
# running_loss:-------
# 0.0007170166220720357
# epoch 813
# **********
# running_loss:-------
# 0.0007169120029498162
# epoch 814
# **********
# running_loss:-------
# 0.0007168082933459986
# epoch 815
# **********
# running_loss:-------
# 0.0007167054799173773
# epoch 816
# **********
# running_loss:-------
# 0.0007166034988867474
# epoch 817
# **********
# running_loss:-------
# 0.0007165023220508854
# epoch 818
# **********
# running_loss:-------
# 0.0007164019780633182
# epoch 819
# **********
# running_loss:-------
# 0.0007163025319099606
# epoch 820
# **********
# running_loss:-------
# 0.0007162038352513376
# epoch 821
# **********
# running_loss:-------
# 0.0007161060173719733
# epoch 822
# **********
# running_loss:-------
# 0.0007160089866943424
# epoch 823
# **********
# running_loss:-------
# 0.0007159127957143606
# epoch 824
# **********
# running_loss:-------
# 0.0007158172623908864
# epoch 825
# **********
# running_loss:-------
# 0.000715722582629671
# epoch 826
# **********
# running_loss:-------
# 0.0007156286250368741
# epoch 827
# **********
# running_loss:-------
# 0.0007155354540533058
# epoch 828
# **********
# running_loss:-------
# 0.0007154430377311134
# epoch 829
# **********
# running_loss:-------
# 0.0007153513708562553
# epoch 830
# **********
# running_loss:-------
# 0.0007152604647574215
# epoch 831
# **********
# running_loss:-------
# 0.0007151702957581244
# epoch 832
# **********
# running_loss:-------
# 0.0007150808164579884
# epoch 833
# **********
# running_loss:-------
# 0.0007149920450113577
# epoch 834
# **********
# running_loss:-------
# 0.0007149040092659525
# epoch 835
# **********
# running_loss:-------
# 0.0007148166730078862
# epoch 836
# **********
# running_loss:-------
# 0.0007147299995492682
# epoch 837
# **********
# running_loss:-------
# 0.000714643955472834
# epoch 838
# **********
# running_loss:-------
# 0.0007145586978871275
# epoch 839
# **********
# running_loss:-------
# 0.0007144740734756347
# epoch 840
# **********
# running_loss:-------
# 0.0007143901235714831
# epoch 841
# **********
# running_loss:-------
# 0.0007143068215593617
# epoch 842
# **********
# running_loss:-------
# 0.0007142241601159126
# epoch 843
# **********
# running_loss:-------
# 0.0007141421408764487
# epoch 844
# **********
# running_loss:-------
# 0.0007140607421789986
# epoch 845
# **********
# running_loss:-------
# 0.0007139799869416436
# epoch 846
# **********
# running_loss:-------
# 0.0007138998764915944
# epoch 847
# **********
# running_loss:-------
# 0.0007138203768664819
# epoch 848
# **********
# running_loss:-------
# 0.0007137414880900064
# epoch 849
# **********
# running_loss:-------
# 0.0007136631804421326
# epoch 850
# **********
# running_loss:-------
# 0.0007135854890939388
# epoch 851
# **********
# running_loss:-------
# 0.0007135083786136446
# epoch 852
# **********
# running_loss:-------
# 0.0007134318890071669
# epoch 853
# **********
# running_loss:-------
# 0.0007133559369446455
# epoch 854
# **********
# running_loss:-------
# 0.0007132805696368546
# epoch 855
# **********
# running_loss:-------
# 0.0007132057866334903
# epoch 856
# **********
# running_loss:-------
# 0.0007131315911814785
# epoch 857
# **********
# running_loss:-------
# 0.0007130579317803116
# epoch 858
# **********
# running_loss:-------
# 0.0007129848227686028
# epoch 859
# **********
# running_loss:-------
# 0.0007129123134427425
# epoch 860
# **********
# running_loss:-------
# 0.0007128402533539395
# epoch 861
# **********
# running_loss:-------
# 0.0007127687694403989
# epoch 862
# **********
# running_loss:-------
# 0.0007126977767843483
# epoch 863
# **********
# running_loss:-------
# 0.000712627355492422
# epoch 864
# **********
# running_loss:-------
# 0.0007125574288708127
# epoch 865
# **********
# running_loss:-------
# 0.0007124879839081175
# epoch 866
# **********
# running_loss:-------
# 0.000712419096990041
# epoch 867
# **********
# running_loss:-------
# 0.0007123506972293221
# epoch 868
# **********
# running_loss:-------
# 0.0007122827859057709
# epoch 869
# **********
# running_loss:-------
# 0.0007122153389636967
# epoch 870
# **********
# running_loss:-------
# 0.000712148431319393
# epoch 871
# **********
# running_loss:-------
# 0.000712081984074935
# epoch 872
# **********
# running_loss:-------
# 0.0007120160348899207
# epoch 873
# **********
# running_loss:-------
# 0.0007119505642827961
# epoch 874
# **********
# running_loss:-------
# 0.0007118856219054542
# epoch 875
# **********
# running_loss:-------
# 0.0007118210635659534
# epoch 876
# **********
# running_loss:-------
# 0.0007117569405277993
# epoch 877
# **********
# running_loss:-------
# 0.0007116933343907384
# epoch 878
# **********
# running_loss:-------
# 0.0007116301814486661
# epoch 879
# **********
# running_loss:-------
# 0.0007115674239205248
# epoch 880
# **********
# running_loss:-------
# 0.0007115051651391328
# epoch 881
# **********
# running_loss:-------
# 0.0007114433027670797
# epoch 882
# **********
# running_loss:-------
# 0.0007113819247083617
# epoch 883
# **********
# running_loss:-------
# 0.0007113210087085025
# epoch 884
# **********
# running_loss:-------
# 0.0007112604603933546
# epoch 885
# **********
# running_loss:-------
# 0.0007112002940067311
# epoch 886
# **********
# running_loss:-------
# 0.0007111405821897071
# epoch 887
# **********
# running_loss:-------
# 0.000711081251874604
# epoch 888
# **********
# running_loss:-------
# 0.0007110223842819649
# epoch 889
# **********
# running_loss:-------
# 0.0007109638841844358
# epoch 890
# **********
# running_loss:-------
# 0.0007109058367604911
# epoch 891
# **********
# running_loss:-------
# 0.0007108481573056603
# epoch 892
# **********
# running_loss:-------
# 0.0007107908545890125
# epoch 893
# **********
# running_loss:-------
# 0.0007107339186564691
# epoch 894
# **********
# running_loss:-------
# 0.0007106773852005128
# epoch 895
# **********
# running_loss:-------
# 0.0007106212178650555
# epoch 896
# **********
# running_loss:-------
# 0.0007105654511338703
# epoch 897
# **********
# running_loss:-------
# 0.0007105100694359341
# epoch 898
# **********
# running_loss:-------
# 0.000710455065353088
# epoch 899
# **********
# running_loss:-------
# 0.0007104004059657712
# epoch 900
# **********
# running_loss:-------
# 0.0007103460506992627
# epoch 901
# **********
# running_loss:-------
# 0.0007102921457837202
# epoch 902
# **********
# running_loss:-------
# 0.0007102385665798569
# epoch 903
# **********
# running_loss:-------
# 0.0007101853694941193
# epoch 904
# **********
# running_loss:-------
# 0.000710132450269382
# epoch 905
# **********
# running_loss:-------
# 0.0007100799570792181
# epoch 906
# **********
# running_loss:-------
# 0.0007100277881787223
# epoch 907
# **********
# running_loss:-------
# 0.0007099759993581359
# epoch 908
# **********
# running_loss:-------
# 0.0007099245188058906
# epoch 909
# **********
# running_loss:-------
# 0.0007098733624722126
# epoch 910
# **********
# running_loss:-------
# 0.0007098225606459417
# epoch 911
# **********
# running_loss:-------
# 0.0007097720214888509
# epoch 912
# **********
# running_loss:-------
# 0.0007097218520072872
# epoch 913
# **********
# running_loss:-------
# 0.0007096720292120687
# epoch 914
# **********
# running_loss:-------
# 0.0007096225200651338
# epoch 915
# **********
# running_loss:-------
# 0.0007095733217461602
# epoch 916
# **********
# running_loss:-------
# 0.0007095244052698184
# epoch 917
# **********
# running_loss:-------
# 0.0007094757765848553
# epoch 918
# **********
# running_loss:-------
# 0.0007094275141625926
# epoch 919
# **********
# running_loss:-------
# 0.000709379512039491
# epoch 920
# **********
# running_loss:-------
# 0.0007093318388749942
# epoch 921
# **********
# running_loss:-------
# 0.0007092844650201676
# epoch 922
# **********
# running_loss:-------
# 0.0007092373823221463
# epoch 923
# **********
# running_loss:-------
# 0.0007091905922266421
# epoch 924
# **********
# running_loss:-------
# 0.0007091441332464597
# epoch 925
# **********
# running_loss:-------
# 0.000709097950017961
# epoch 926
# **********
# running_loss:-------
# 0.0007090520087683782
# epoch 927
# **********
# running_loss:-------
# 0.0007090064299420653
# epoch 928
# **********
# running_loss:-------
# 0.0007089610871696217
# epoch 929
# **********
# running_loss:-------
# 0.0007089159970411785
# epoch 930
# **********
# running_loss:-------
# 0.0007088711973822354
# epoch 931
# **********
# running_loss:-------
# 0.0007088266378535938
# epoch 932
# **********
# running_loss:-------
# 0.000708782421432569
# epoch 933
# **********
# running_loss:-------
# 0.0007087384499529838
# epoch 934
# **********
# running_loss:-------
# 0.0007086947464751207
# epoch 935
# **********
# running_loss:-------
# 0.0007086513196732485
# epoch 936
# **********
# running_loss:-------
# 0.0007086081070262721
# epoch 937
# **********
# running_loss:-------
# 0.0007085651940918689
# epoch 938
# **********
# running_loss:-------
# 0.0007085225469076699
# epoch 939
# **********
# running_loss:-------
# 0.0007084801573682112
# epoch 940
# **********
# running_loss:-------
# 0.000708437963639703
# epoch 941
# **********
# running_loss:-------
# 0.000708396088062514
# epoch 942
# **********
# running_loss:-------
# 0.0007083544298397462
# epoch 943
# **********
# running_loss:-------
# 0.0007083130020065027
# epoch 944
# **********
# running_loss:-------
# 0.0007082717939213992
# epoch 945
# **********
# running_loss:-------
# 0.0007082308846482619
# epoch 946
# **********
# running_loss:-------
# 0.000708190207423662
# epoch 947
# **********
# running_loss:-------
# 0.0007081497417943376
# epoch 948
# **********
# running_loss:-------
# 0.0007081095453517447
# epoch 949
# **********
# running_loss:-------
# 0.0007080695849393209
# epoch 950
# **********
# running_loss:-------
# 0.0007080298544187174
# epoch 951
# **********
# running_loss:-------
# 0.0007079903615872962
# epoch 952
# **********
# running_loss:-------
# 0.0007079510800193477
# epoch 953
# **********
# running_loss:-------
# 0.0007079119838342671
# epoch 954
# **********
# running_loss:-------
# 0.0007078731811997111
# epoch 955
# **********
# running_loss:-------
# 0.0007078345877430113
# epoch 956
# **********
# running_loss:-------
# 0.0007077961625813442
# epoch 957
# **********
# running_loss:-------
# 0.0007077580121048523
# epoch 958
# **********
# running_loss:-------
# 0.0007077200503529547
# epoch 959
# **********
# running_loss:-------
# 0.0007076823116198231
# epoch 960
# **********
# running_loss:-------
# 0.0007076448111683782
# epoch 961
# **********
# running_loss:-------
# 0.0007076074813819848
# epoch 962
# **********
# running_loss:-------
# 0.0007075703339685355
# epoch 963
# **********
# running_loss:-------
# 0.0007075334494375679
# epoch 964
# **********
# running_loss:-------
# 0.0007074967579683289
# epoch 965
# **********
# running_loss:-------
# 0.0007074603316330894
# epoch 966
# **********
# running_loss:-------
# 0.0007074240088913702
# epoch 967
# **********
# running_loss:-------
# 0.0007073879422301787
# epoch 968
# **********
# running_loss:-------
# 0.0007073520390528819
# epoch 969
# **********
# running_loss:-------
# 0.0007073163484425681
# epoch 970
# **********
# running_loss:-------
# 0.0007072808540461082
# epoch 971
# **********
# running_loss:-------
# 0.0007072455250058575
# epoch 972
# **********
# running_loss:-------
# 0.0007072104248383191
# epoch 973
# **********
# running_loss:-------
# 0.0007071755012134788
# epoch 974
# **********
# running_loss:-------
# 0.0007071408063428498
# epoch 975
# **********
# running_loss:-------
# 0.0007071062979926977
# epoch 976
# **********
# running_loss:-------
# 0.0007070719479123989
# epoch 977
# **********
# running_loss:-------
# 0.0007070377771240197
# epoch 978
# **********
# running_loss:-------
# 0.0007070038239507638
# epoch 979
# **********
# running_loss:-------
# 0.0007069700344036036
# epoch 980
# **********
# running_loss:-------
# 0.0007069364119190662
# epoch 981
# **********
# running_loss:-------
# 0.0007069029998684951
# epoch 982
# **********
# running_loss:-------
# 0.0007068697217002842
# epoch 983
# **********
# running_loss:-------
# 0.0007068367067700577
# epoch 984
# **********
# running_loss:-------
# 0.0007068037877781909
# epoch 985
# **********
# running_loss:-------
# 0.0007067709841588376
# epoch 986
# **********
# running_loss:-------
# 0.0007067384282538458
# epoch 987
# **********
# running_loss:-------
# 0.000706706024527759
# epoch 988
# **********
# running_loss:-------
# 0.0007066738108060769
# epoch 989
# **********
# running_loss:-------
# 0.0007066418625264966
# epoch 990
# **********
# running_loss:-------
# 0.0007066099550349392
# epoch 991
# **********
# running_loss:-------
# 0.0007065782051259297
# epoch 992
# **********
# running_loss:-------
# 0.0007065466850139398
# epoch 993
# **********
# running_loss:-------
# 0.0007065153099470984
# epoch 994
# **********
# running_loss:-------
# 0.0007064841289610938
# epoch 995
# **********
# running_loss:-------
# 0.0007064531101554735
# epoch 996
# **********
# running_loss:-------
# 0.0007064222012713236
# epoch 997
# **********
# running_loss:-------
# 0.0007063914851645002
# epoch 998
# **********
# running_loss:-------
# 0.0007063609250760122
# epoch 999
# **********
# running_loss:-------
# 0.0007063305060273409
# epoch 1000
# **********
# running_loss:-------
# 0.0007063002371193586
# Wall time: 1h 2min 57s

# %%
print(train_x.size(),train_y.size(),out.size())
out = model(train_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d680505c1d3a> in <module>
#       1
# ----> 2 print(train_x.size(),train_y.size(),out.size())
#       3 out = model(train_x)
#
# NameError: name 'train_x' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(losslist,'r-.') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-02e8ea6ca590> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(losslist,'r-.')
#       3 plt.show()
#
# NameError: name 'losslist' is not defined

# %% [raw]
# 0.00797845292009054

# %%
out.detach().numpy().shape
# Out:
# (100, 1)

# %%
x=range(0,100)
plt.figure(num=1,figsize=(18,5))#定义编号为1 大小为(8,5)
plt.plot(x,train_y.numpy(),'r-.',label='train_y') 
plt.plot(x,out.detach().numpy(),'b-.',label='out') 
plt.legend(loc='best')#显示在最好的位置
plt.show()

# %%
model.eval()
    
test_x=test_dataset[:,0:8]

test_x=test_x.view(-1,1,8)

test_y=test_dataset[:,8]

test_y=test_y.view(-1,1)

test_x=Variable(test_x)

test_y=Variable(test_y)

out = model(test_x)

# %%
#x=range(0,13123)
x=range(1200,1300)
plt.figure(num=1,figsize=(18,5))#定义编号为1 大小为(8,5)
plt.plot(x,test_y.numpy()[1200:1300],'r-.',label='test_y') 
plt.plot(x,out.detach().numpy()[1200:1300],'b-.',label='out') 
plt.legend(loc='best')#显示在最好的位置
plt.show()

# %%
# 保存模型
torch.save(model.state_dict(), './weatherlstm-0.01-false.pth')
