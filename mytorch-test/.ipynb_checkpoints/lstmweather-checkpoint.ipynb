# %%
import csv

import pandas as pd

import numpy as np

import torch

from torch import nn, optim

from torch.autograd import Variable

from torch.utils.data import Dataset

from torch.utils.data import DataLoader

import time

# %%
# 定义自己的类
class MyDataset(Dataset):
    
    # 初始化
    def __init__(self, file_name):
        # 读入数据
        self.data = pd.read_csv(file_name)
    
    # 返回df的长度
    def __len__(self):
        return len(self.data)
    
    # 获取第idx+1列的数据
    def __getitem__(self, idx):
        return self.data.values[idx,1:10]

# 通过实例化对象来访问该类
# 假设同目录下存在名为median_benchmark.csv的文件
ds = MyDataset('formatweather.csv')
ds=np.asarray(ds[:], dtype = np.float32)#####源文件float32 ,不知道为什么读取变为float64，这里再进行处理  最大最小化时变化
##dl = DataLoader(ds, batch_size=100, shuffle=False)

#####处理为torch，分为trainx，trainy
torchds=torch.from_numpy(ds[:])

# %%
train_dataset =torchds[:30700]  ##0.7*43823
test_dataset =torchds[30700:]
dl = DataLoader(train_dataset, batch_size=100, shuffle=False)

# %%
# 定义 Recurrent Network 模型

class Rnn(nn.Module):

    def __init__(self, in_dim, hidden_dim, n_layer, n_class):

        super(Rnn, self).__init__()

        self.n_layer = n_layer

        self.hidden_dim = hidden_dim

        self.lstm = nn.LSTM(in_dim, hidden_dim, n_layer, batch_first=True)

        self.classifier = nn.Linear(hidden_dim, n_class)



    def forward(self, x):

        # h0 = Variable(torch.zeros(self.n_layer, x.size(1),

        #   self.hidden_dim)).cuda()

        # c0 = Variable(torch.zeros(self.n_layer, x.size(1),

        #   self.hidden_dim)).cuda()

        out, _ = self.lstm(x) #out 100 28 128 _ [0]2 100 128 [1]2 100 128

        out = out[:, -1, :]  #100,128

        out = self.classifier(out) #100,10

        return out

# %%
model = Rnn(8, 4, 2, 1)  
##model.load_state_dict(torch.load('./weathercnn.pth'))
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01) ####速度很快

# %%
# %%time 
losslist=[]
for epoch in range(1000):
 
    print('epoch {}'.format(epoch + 1))

    print('*' * 10)

    running_loss = 0.0

    for i, data in enumerate(dl, 1):
        
            train_x=data[:,0:8]
            
            train_x=train_x.view(-1,1,8)
            
            train_y=data[:,8]
            
            train_y=train_y.view(-1,1)
            
            train_x=Variable(train_x)
            
            train_y=Variable(train_y)
        
            out = model(train_x)

            loss = criterion(out, train_y)
            
            running_loss += loss.item() * train_y.size(0)
            

            # 向后传播

            optimizer.zero_grad()

            loss.backward()

            optimizer.step()
            
    losslist.append(running_loss / (len(train_dataset)))   
           
                
    print('running_loss:-------')
    print(running_loss / (len(train_dataset)))            
    #print(out,train_y)
# Out:
# epoch 1
# **********
# running_loss:-------
# 0.012850855371261816
# epoch 2
# **********
# running_loss:-------
# 0.008369551231006842
# epoch 3
# **********
# running_loss:-------
# 0.008368329470702264
# epoch 4
# **********
# running_loss:-------
# 0.008366789001365612
# epoch 5
# **********
# running_loss:-------
# 0.008365262528388087
# epoch 6
# **********
# running_loss:-------
# 0.008363750290572784
# epoch 7
# **********
# running_loss:-------
# 0.008362252306299195
# epoch 8
# **********
# running_loss:-------
# 0.008360768083634378
# epoch 9
# **********
# running_loss:-------
# 0.008359297273593067
# epoch 10
# **********
# running_loss:-------
# 0.008357839697191446
# epoch 11
# **********
# running_loss:-------
# 0.008356395193078636
# epoch 12
# **********
# running_loss:-------
# 0.008354963500860678
# epoch 13
# **********
# running_loss:-------
# 0.008353544188625349
# epoch 14
# **********
# running_loss:-------
# 0.008352137255626094
# epoch 15
# **********
# running_loss:-------
# 0.008350742476651879
# epoch 16
# **********
# running_loss:-------
# 0.008349359219535751
# epoch 17
# **********
# running_loss:-------
# 0.008347987839899023
# epoch 18
# **********
# running_loss:-------
# 0.00834662780279291
# epoch 19
# **********
# running_loss:-------
# 0.00834527896396622
# epoch 20
# **********
# running_loss:-------
# 0.008343941051340798
# epoch 21
# **********
# running_loss:-------
# 0.008342613900757296
# epoch 22
# **********
# running_loss:-------
# 0.008341297152387612
# epoch 23
# **********
# running_loss:-------
# 0.008339990962830737
# epoch 24
# **********
# running_loss:-------
# 0.008338695006161691
# epoch 25
# **********
# running_loss:-------
# 0.008337408648850757
# epoch 26
# **********
# running_loss:-------
# 0.0083361323160082
# epoch 27
# **********
# running_loss:-------
# 0.008334865395280423
# epoch 28
# **********
# running_loss:-------
# 0.00833360786050242
# epoch 29
# **********
# running_loss:-------
# 0.008332359678482072
# epoch 30
# **********
# running_loss:-------
# 0.008331120434714954
# epoch 31
# **********
# running_loss:-------
# 0.008329890187633875
# epoch 32
# **********
# running_loss:-------
# 0.008328668435968016
# epoch 33
# **********
# running_loss:-------
# 0.008327454975125508
# epoch 34
# **********
# running_loss:-------
# 0.008326249849176848
# epoch 35
# **********
# running_loss:-------
# 0.00832505322755468
# epoch 36
# **********
# running_loss:-------
# 0.008323864401943343
# epoch 37
# **********
# running_loss:-------
# 0.008322683492443542
# epoch 38
# **********
# running_loss:-------
# 0.008321510037423017
# epoch 39
# **********
# running_loss:-------
# 0.00832034425684321
# epoch 40
# **********
# running_loss:-------
# 0.008319185669234811
# epoch 41
# **********
# running_loss:-------
# 0.008318034560279883
# epoch 42
# **********
# running_loss:-------
# 0.008316890390656952
# epoch 43
# **********
# running_loss:-------
# 0.008315753077593115
# epoch 44
# **********
# running_loss:-------
# 0.008314622352517844
# epoch 45
# **********
# running_loss:-------
# 0.008313498515274064
# epoch 46
# **********
# running_loss:-------
# 0.008312380838194912
# epoch 47
# **********
# running_loss:-------
# 0.008311269719218391
# epoch 48
# **********
# running_loss:-------
# 0.008310164817606902
# epoch 49
# **********
# running_loss:-------
# 0.008309065860535734
# epoch 50
# **********
# running_loss:-------
# 0.00830797277998535
# epoch 51
# **********
# running_loss:-------
# 0.008306885447263728
# epoch 52
# **********
# running_loss:-------
# 0.008305803788912137
# epoch 53
# **********
# running_loss:-------
# 0.008304727541337095
# epoch 54
# **********
# running_loss:-------
# 0.008303656905065883
# epoch 55
# **********
# running_loss:-------
# 0.00830259144143173
# epoch 56
# **********
# running_loss:-------
# 0.008301531028603822
# epoch 57
# **********
# running_loss:-------
# 0.008300475603041955
# epoch 58
# **********
# running_loss:-------
# 0.008299425113601124
# epoch 59
# **********
# running_loss:-------
# 0.008298379207112985
# epoch 60
# **********
# running_loss:-------
# 0.008297338110198728
# epoch 61
# **********
# running_loss:-------
# 0.008296301467699194
# epoch 62
# **********
# running_loss:-------
# 0.008295269262621347
# epoch 63
# **********
# running_loss:-------
# 0.008294241171718328
# epoch 64
# **********
# running_loss:-------
# 0.008293217385397445
# epoch 65
# **********
# running_loss:-------
# 0.00829219760369727
# epoch 66
# **********
# running_loss:-------
# 0.008291181590480989
# epoch 67
# **********
# running_loss:-------
# 0.008290169522682347
# epoch 68
# **********
# running_loss:-------
# 0.008289161082920285
# epoch 69
# **********
# running_loss:-------
# 0.008288156493075956
# epoch 70
# **********
# running_loss:-------
# 0.008287155195246948
# epoch 71
# **********
# running_loss:-------
# 0.008286157160779729
# epoch 72
# **********
# running_loss:-------
# 0.008285162506456974
# epoch 73
# **********
# running_loss:-------
# 0.008284171008987368
# epoch 74
# **********
# running_loss:-------
# 0.008283182604984757
# epoch 75
# **********
# running_loss:-------
# 0.008282197178235272
# epoch 76
# **********
# running_loss:-------
# 0.008281214548617485
# epoch 77
# **********
# running_loss:-------
# 0.008280234537597884
# epoch 78
# **********
# running_loss:-------
# 0.00827925715715691
# epoch 79
# **********
# running_loss:-------
# 0.008278282453154434
# epoch 80
# **********
# running_loss:-------
# 0.008277310105590513
# epoch 81
# **********
# running_loss:-------
# 0.00827634006973105
# epoch 82
# **********
# running_loss:-------
# 0.008275372172280268
# epoch 83
# **********
# running_loss:-------
# 0.008274406655726641
# epoch 84
# **********
# running_loss:-------
# 0.00827344299531246
# epoch 85
# **********
# running_loss:-------
# 0.008272481448196613
# epoch 86
# **********
# running_loss:-------
# 0.008271521518843727
# epoch 87
# **********
# running_loss:-------
# 0.00827056343431345
# epoch 88
# **********
# running_loss:-------
# 0.008269606854271083
# epoch 89
# **********
# running_loss:-------
# 0.008268652054871218
# epoch 90
# **********
# running_loss:-------
# 0.008267698514508273
# epoch 91
# **********
# running_loss:-------
# 0.008266746380881816
# epoch 92
# **********
# running_loss:-------
# 0.008265795529589564
# epoch 93
# **********
# running_loss:-------
# 0.008264845785451579
# epoch 94
# **********
# running_loss:-------
# 0.00826389729628593
# epoch 95
# **********
# running_loss:-------
# 0.008262949567742256
# epoch 96
# **********
# running_loss:-------
# 0.008262002908254797
# epoch 97
# **********
# running_loss:-------
# 0.008261057016955594
# epoch 98
# **********
# running_loss:-------
# 0.008260111763819496
# epoch 99
# **********
# running_loss:-------
# 0.008259167143217705
# epoch 100
# **********
# running_loss:-------
# 0.008258222957016656
# epoch 101
# **********
# running_loss:-------
# 0.008257279335057823
# epoch 102
# **********
# running_loss:-------
# 0.008256335986812458
# epoch 103
# **********
# running_loss:-------
# 0.008255392732301334
# epoch 104
# **********
# running_loss:-------
# 0.008254449858036023
# epoch 105
# **********
# running_loss:-------
# 0.008253507135511163
# epoch 106
# **********
# running_loss:-------
# 0.00825256415363515
# epoch 107
# **********
# running_loss:-------
# 0.008251621117384979
# epoch 108
# **********
# running_loss:-------
# 0.008250678059058086
# epoch 109
# **********
# running_loss:-------
# 0.008249734509183374
# epoch 110
# **********
# running_loss:-------
# 0.008248790689997504
# epoch 111
# **********
# running_loss:-------
# 0.008247846475640632
# epoch 112
# **********
# running_loss:-------
# 0.008246901449931534
# epoch 113
# **********
# running_loss:-------
# 0.008245956094718726
# epoch 114
# **********
# running_loss:-------
# 0.008245009665792618
# epoch 115
# **********
# running_loss:-------
# 0.00824406277027499
# epoch 116
# **********
# running_loss:-------
# 0.008243114778398529
# epoch 117
# **********
# running_loss:-------
# 0.008242165822552485
# epoch 118
# **********
# running_loss:-------
# 0.008241215846869591
# epoch 119
# **********
# running_loss:-------
# 0.008240264537399386
# epoch 120
# **********
# running_loss:-------
# 0.008239312071117095
# epoch 121
# **********
# running_loss:-------
# 0.008238358159437385
# epoch 122
# **********
# running_loss:-------
# 0.008237402856337431
# epoch 123
# **********
# running_loss:-------
# 0.008236445907620873
# epoch 124
# **********
# running_loss:-------
# 0.008235487439911884
# epoch 125
# **********
# running_loss:-------
# 0.008234527330289445
# epoch 126
# **********
# running_loss:-------
# 0.008233565186971678
# epoch 127
# **********
# running_loss:-------
# 0.00823260113019556
# epoch 128
# **********
# running_loss:-------
# 0.008231635394912899
# epoch 129
# **********
# running_loss:-------
# 0.008230667431492646
# epoch 130
# **********
# running_loss:-------
# 0.008229697279377836
# epoch 131
# **********
# running_loss:-------
# 0.008228725039146142
# epoch 132
# **********
# running_loss:-------
# 0.00822775029887645
# epoch 133
# **********
# running_loss:-------
# 0.008226773197866617
# epoch 134
# **********
# running_loss:-------
# 0.00822579355999462
# epoch 135
# **********
# running_loss:-------
# 0.008224811286638054
# epoch 136
# **********
# running_loss:-------
# 0.008223826359867728
# epoch 137
# **********
# running_loss:-------
# 0.008222838737651358
# epoch 138
# **********
# running_loss:-------
# 0.008221847988023398
# epoch 139
# **********
# running_loss:-------
# 0.008220854370293526
# epoch 140
# **********
# running_loss:-------
# 0.00821985760964622
# epoch 141
# **********
# running_loss:-------
# 0.00821885770858777
# epoch 142
# **********
# running_loss:-------
# 0.008217854560271807
# epoch 143
# **********
# running_loss:-------
# 0.008216848121546215
# epoch 144
# **********
# running_loss:-------
# 0.008215838076688941
# epoch 145
# **********
# running_loss:-------
# 0.008214824511376168
# epoch 146
# **********
# running_loss:-------
# 0.008213807364739886
# epoch 147
# **********
# running_loss:-------
# 0.008212786286592047
# epoch 148
# **********
# running_loss:-------
# 0.008211761602946507
# epoch 149
# **********
# running_loss:-------
# 0.008210733025294958
# epoch 150
# **********
# running_loss:-------
# 0.008209700190805304
# epoch 151
# **********
# running_loss:-------
# 0.00820866337605873
# epoch 152
# **********
# running_loss:-------
# 0.008207622303401616
# epoch 153
# **********
# running_loss:-------
# 0.008206576705963923
# epoch 154
# **********
# running_loss:-------
# 0.008205526888547839
# epoch 155
# **********
# running_loss:-------
# 0.00820447239280951
# epoch 156
# **********
# running_loss:-------
# 0.008203413366608481
# epoch 157
# **********
# running_loss:-------
# 0.008202349364381226
# epoch 158
# **********
# running_loss:-------
# 0.008201280837094914
# epoch 159
# **********
# running_loss:-------
# 0.008200207100904331
# epoch 160
# **********
# running_loss:-------
# 0.008199128313978604
# epoch 161
# **********
# running_loss:-------
# 0.00819804444115258
# epoch 162
# **********
# running_loss:-------
# 0.008196955389687424
# epoch 163
# **********
# running_loss:-------
# 0.008195860877509427
# epoch 164
# **********
# running_loss:-------
# 0.008194760844171261
# epoch 165
# **********
# running_loss:-------
# 0.00819365534112011
# epoch 166
# **********
# running_loss:-------
# 0.00819254396919741
# epoch 167
# **********
# running_loss:-------
# 0.00819142682508808
# epoch 168
# **********
# running_loss:-------
# 0.008190303954414979
# epoch 169
# **********
# running_loss:-------
# 0.00818917494974818
# epoch 170
# **********
# running_loss:-------
# 0.008188039724629401
# epoch 171
# **********
# running_loss:-------
# 0.008186898146894545
# epoch 172
# **********
# running_loss:-------
# 0.008185750407584898
# epoch 173
# **********
# running_loss:-------
# 0.008184596083752837
# epoch 174
# **********
# running_loss:-------
# 0.008183435197155134
# epoch 175
# **********
# running_loss:-------
# 0.008182267510594386
# epoch 176
# **********
# running_loss:-------
# 0.008181092848612178
# epoch 177
# **********
# running_loss:-------
# 0.00817991134168397
# epoch 178
# **********
# running_loss:-------
# 0.008178722738747748
# epoch 179
# **********
# running_loss:-------
# 0.008177526824143652
# epoch 180
# **********
# running_loss:-------
# 0.008176323571665204
# epoch 181
# **********
# running_loss:-------
# 0.008175112875893965
# epoch 182
# **********
# running_loss:-------
# 0.008173894803332664
# epoch 183
# **********
# running_loss:-------
# 0.008172668831291436
# epoch 184
# **********
# running_loss:-------
# 0.008171435024833222
# epoch 185
# **********
# running_loss:-------
# 0.008170193258856581
# epoch 186
# **********
# running_loss:-------
# 0.008168943611376607
# epoch 187
# **********
# running_loss:-------
# 0.008167685499564207
# epoch 188
# **********
# running_loss:-------
# 0.008166419024322934
# epoch 189
# **********
# running_loss:-------
# 0.008165144000998697
# epoch 190
# **********
# running_loss:-------
# 0.008163860399551508
# epoch 191
# **********
# running_loss:-------
# 0.008162567852658087
# epoch 192
# **********
# running_loss:-------
# 0.008161266398825313
# epoch 193
# **********
# running_loss:-------
# 0.00815995594408194
# epoch 194
# **********
# running_loss:-------
# 0.008158636245032966
# epoch 195
# **********
# running_loss:-------
# 0.00815730720150955
# epoch 196
# **********
# running_loss:-------
# 0.008155968653778349
# epoch 197
# **********
# running_loss:-------
# 0.00815462027986639
# epoch 198
# **********
# running_loss:-------
# 0.008153262205272092
# epoch 199
# **********
# running_loss:-------
# 0.008151894166893747
# epoch 200
# **********
# running_loss:-------
# 0.00815051588714883
# epoch 201
# **********
# running_loss:-------
# 0.008149127424410907
# epoch 202
# **********
# running_loss:-------
# 0.008147728526705504
# epoch 203
# **********
# running_loss:-------
# 0.008146319159987302
# epoch 204
# **********
# running_loss:-------
# 0.008144899028543137
# epoch 205
# **********
# running_loss:-------
# 0.008143467872530074
# epoch 206
# **********
# running_loss:-------
# 0.008142025445869065
# epoch 207
# **********
# running_loss:-------
# 0.008140571979311062
# epoch 208
# **********
# running_loss:-------
# 0.008139107011354162
# epoch 209
# **********
# running_loss:-------
# 0.008137630494283959
# epoch 210
# **********
# running_loss:-------
# 0.008136142257038428
# epoch 211
# **********
# running_loss:-------
# 0.00813464211326299
# epoch 212
# **********
# running_loss:-------
# 0.008133129693981273
# epoch 213
# **********
# running_loss:-------
# 0.00813160515909252
# epoch 214
# **********
# running_loss:-------
# 0.008130067921258682
# epoch 215
# **********
# running_loss:-------
# 0.008128518085252358
# epoch 216
# **********
# running_loss:-------
# 0.008126955488816144
# epoch 217
# **********
# running_loss:-------
# 0.008125379981430144
# epoch 218
# **********
# running_loss:-------
# 0.008123791236742775
# epoch 219
# **********
# running_loss:-------
# 0.008122188998258758
# epoch 220
# **********
# running_loss:-------
# 0.008120573059288752
# epoch 221
# **********
# running_loss:-------
# 0.008118943289102527
# epoch 222
# **********
# running_loss:-------
# 0.008117299495136053
# epoch 223
# **********
# running_loss:-------
# 0.008115641515682954
# epoch 224
# **********
# running_loss:-------
# 0.00811396910927979
# epoch 225
# **********
# running_loss:-------
# 0.008112281891770223
# epoch 226
# **********
# running_loss:-------
# 0.008110579843874146
# epoch 227
# **********
# running_loss:-------
# 0.008108862636022675
# epoch 228
# **********
# running_loss:-------
# 0.008107130139511943
# epoch 229
# **********
# running_loss:-------
# 0.008105382294380473
# epoch 230
# **********
# running_loss:-------
# 0.008103618374543391
# epoch 231
# **********
# running_loss:-------
# 0.008101838602669886
# epoch 232
# **********
# running_loss:-------
# 0.008100042597127686
# epoch 233
# **********
# running_loss:-------
# 0.008098230268211581
# epoch 234
# **********
# running_loss:-------
# 0.00809640121043506
# epoch 235
# **********
# running_loss:-------
# 0.0080945552728457
# epoch 236
# **********
# running_loss:-------
# 0.008092691889340824
# epoch 237
# **********
# running_loss:-------
# 0.008090811062699274
# epoch 238
# **********
# running_loss:-------
# 0.008088912825390308
# epoch 239
# **********
# running_loss:-------
# 0.008086996433038434
# epoch 240
# **********
# running_loss:-------
# 0.008085062002941804
# epoch 241
# **********
# running_loss:-------
# 0.008083109163985105
# epoch 242
# **********
# running_loss:-------
# 0.008081137612183804
# epoch 243
# **********
# running_loss:-------
# 0.00807914711310157
# epoch 244
# **********
# running_loss:-------
# 0.008077137289538067
# epoch 245
# **********
# running_loss:-------
# 0.008075108019069974
# epoch 246
# **********
# running_loss:-------
# 0.008073058925231661
# epoch 247
# **********
# running_loss:-------
# 0.008070989771400456
# epoch 248
# **********
# running_loss:-------
# 0.00806890009968873
# epoch 249
# **********
# running_loss:-------
# 0.008066789820865278
# epoch 250
# **********
# running_loss:-------
# 0.00806465846510943
# epoch 251
# **********
# running_loss:-------
# 0.008062505700962211
# epoch 252
# **********
# running_loss:-------
# 0.008060331459065023
# epoch 253
# **********
# running_loss:-------
# 0.008058135160102326
# epoch 254
# **********
# running_loss:-------
# 0.008055916823425326
# epoch 255
# **********
# running_loss:-------
# 0.008053675756253835
# epoch 256
# **********
# running_loss:-------
# 0.008051411624391509
# epoch 257
# **********
# running_loss:-------
# 0.008049124827909364
# epoch 258
# **********
# running_loss:-------
# 0.008046814222443839
# epoch 259
# **********
# running_loss:-------
# 0.008044479804416206
# epoch 260
# **********
# running_loss:-------
# 0.008042120854585019
# epoch 261
# **********
# running_loss:-------
# 0.00803973746139938
# epoch 262
# **********
# running_loss:-------
# 0.008037328974206186
# epoch 263
# **********
# running_loss:-------
# 0.008034895196981183
# epoch 264
# **********
# running_loss:-------
# 0.00803243540812476
# epoch 265
# **********
# running_loss:-------
# 0.008029949892335419
# epoch 266
# **********
# running_loss:-------
# 0.008027437840287303
# epoch 267
# **********
# running_loss:-------
# 0.008024898793583233
# epoch 268
# **********
# running_loss:-------
# 0.008022332743181584
# epoch 269
# **********
# running_loss:-------
# 0.00801973892159918
# epoch 270
# **********
# running_loss:-------
# 0.008017117101634176
# epoch 271
# **********
# running_loss:-------
# 0.008014467007096428
# epoch 272
# **********
# running_loss:-------
# 0.008011787907937211
# epoch 273
# **********
# running_loss:-------
# 0.008009079439375085
# epoch 274
# **********
# running_loss:-------
# 0.00800634153483622
# epoch 275
# **********
# running_loss:-------
# 0.008003573408007643
# epoch 276
# **********
# running_loss:-------
# 0.008000774643685767
# epoch 277
# **********
# running_loss:-------
# 0.007997944654461436
# epoch 278
# **********
# running_loss:-------
# 0.007995083097025584
# epoch 279
# **********
# running_loss:-------
# 0.00799218992428594
# epoch 280
# **********
# running_loss:-------
# 0.007989264340070247
# epoch 281
# **********
# running_loss:-------
# 0.007986305765572523
# epoch 282
# **********
# running_loss:-------
# 0.007983313754411582
# epoch 283
# **********
# running_loss:-------
# 0.007980287628679108
# epoch 284
# **********
# running_loss:-------
# 0.00797722718496824
# epoch 285
# **********
# running_loss:-------
# 0.007974131947545109
# epoch 286
# **********
# running_loss:-------
# 0.007971001302349704
# epoch 287
# **********
# running_loss:-------
# 0.007967834872963795
# epoch 288
# **********
# running_loss:-------
# 0.007964631666835373
# epoch 289
# **********
# running_loss:-------
# 0.007961391459725109
# epoch 290
# **********
# running_loss:-------
# 0.0079581138341068
# epoch 291
# **********
# running_loss:-------
# 0.007954798093905934
# epoch 292
# **********
# running_loss:-------
# 0.007951443361397909
# epoch 293
# **********
# running_loss:-------
# 0.007948049219246122
# epoch 294
# **********
# running_loss:-------
# 0.007944615523969635
# epoch 295
# **********
# running_loss:-------
# 0.007941141075521298
# epoch 296
# **********
# running_loss:-------
# 0.007937625393794556
# epoch 297
# **********
# running_loss:-------
# 0.007934068410758024
# epoch 298
# **********
# running_loss:-------
# 0.00793046885469518
# epoch 299
# **********
# running_loss:-------
# 0.007926826670882292
# epoch 300
# **********
# running_loss:-------
# 0.007923140623887825
# epoch 301
# **********
# running_loss:-------
# 0.007919410415207918
# epoch 302
# **********
# running_loss:-------
# 0.007915635199077672
# epoch 303
# **********
# running_loss:-------
# 0.00791181421834719
# epoch 304
# **********
# running_loss:-------
# 0.007907947172972102
# epoch 305
# **********
# running_loss:-------
# 0.007904033323565797
# epoch 306
# **********
# running_loss:-------
# 0.007900072167625049
# epoch 307
# **********
# running_loss:-------
# 0.007896062601112164
# epoch 308
# **********
# running_loss:-------
# 0.0078920038417669
# epoch 309
# **********
# running_loss:-------
# 0.007887894975366367
# epoch 310
# **********
# running_loss:-------
# 0.00788373561633221
# epoch 311
# **********
# running_loss:-------
# 0.00787952503081182
# epoch 312
# **********
# running_loss:-------
# 0.0078752620762547
# epoch 313
# **********
# running_loss:-------
# 0.00787094597741586
# epoch 314
# **********
# running_loss:-------
# 0.007866576319399816
# epoch 315
# **********
# running_loss:-------
# 0.0078621525506558
# epoch 316
# **********
# running_loss:-------
# 0.007857673389667263
# epoch 317
# **********
# running_loss:-------
# 0.007853137910207173
# epoch 318
# **********
# running_loss:-------
# 0.007848545431321735
# epoch 319
# **********
# running_loss:-------
# 0.007843894966206239
# epoch 320
# **********
# running_loss:-------
# 0.007839185652576753
# epoch 321
# **********
# running_loss:-------
# 0.007834416973295186
# epoch 322
# **********
# running_loss:-------
# 0.007829587770157064
# epoch 323
# **********
# running_loss:-------
# 0.007824697320022262
# epoch 324
# **********
# running_loss:-------
# 0.007819744020521092
# epoch 325
# **********
# running_loss:-------
# 0.00781472731685586
# epoch 326
# **********
# running_loss:-------
# 0.0078096467828971915
# epoch 327
# **********
# running_loss:-------
# 0.007804501138526851
# epoch 328
# **********
# running_loss:-------
# 0.0077992890220031546
# epoch 329
# **********
# running_loss:-------
# 0.0077940094618791115
# epoch 330
# **********
# running_loss:-------
# 0.007788661534368805
# epoch 331
# **********
# running_loss:-------
# 0.0077832442755145035
# epoch 332
# **********
# running_loss:-------
# 0.007777756764729817
# epoch 333
# **********
# running_loss:-------
# 0.007772197918205163
# epoch 334
# **********
# running_loss:-------
# 0.007766566470824523
# epoch 335
# **********
# running_loss:-------
# 0.007760861973256041
# epoch 336
# **********
# running_loss:-------
# 0.007755082998724718
# epoch 337
# **********
# running_loss:-------
# 0.007749228118132938
# epoch 338
# **********
# running_loss:-------
# 0.007743295757337936
# epoch 339
# **********
# running_loss:-------
# 0.0077372852328263
# epoch 340
# **********
# running_loss:-------
# 0.007731196147003681
# epoch 341
# **********
# running_loss:-------
# 0.007725027069990358
# epoch 342
# **********
# running_loss:-------
# 0.007718776286603748
# epoch 343
# **********
# running_loss:-------
# 0.007712442078438044
# epoch 344
# **********
# running_loss:-------
# 0.0077060238495757286
# epoch 345
# **********
# running_loss:-------
# 0.007699520500138492
# epoch 346
# **********
# running_loss:-------
# 0.007692930965750904
# epoch 347
# **********
# running_loss:-------
# 0.007686253648593716
# epoch 348
# **********
# running_loss:-------
# 0.007679487277862862
# epoch 349
# **********
# running_loss:-------
# 0.007672630170821319
# epoch 350
# **********
# running_loss:-------
# 0.007665681495900601
# epoch 351
# **********
# running_loss:-------
# 0.0076586396868264075
# epoch 352
# **********
# running_loss:-------
# 0.007651503547142163
# epoch 353
# **********
# running_loss:-------
# 0.007644271204864844
# epoch 354
# **********
# running_loss:-------
# 0.0076369416462663256
# epoch 355
# **********
# running_loss:-------
# 0.007629513690437354
# epoch 356
# **********
# running_loss:-------
# 0.007621985389601708
# epoch 357
# **********
# running_loss:-------
# 0.007614355675046824
# epoch 358
# **********
# running_loss:-------
# 0.0076066230436594
# epoch 359
# **********
# running_loss:-------
# 0.007598785865316827
# epoch 360
# **********
# running_loss:-------
# 0.007590842599506909
# epoch 361
# **********
# running_loss:-------
# 0.007582791582666071
# epoch 362
# **********
# running_loss:-------
# 0.007574631560604082
# epoch 363
# **********
# running_loss:-------
# 0.007566361295791944
# epoch 364
# **********
# running_loss:-------
# 0.007557978593687078
# epoch 365
# **********
# running_loss:-------
# 0.007549482583686791
# epoch 366
# **********
# running_loss:-------
# 0.007540871170030889
# epoch 367
# **********
# running_loss:-------
# 0.007532142996120627
# epoch 368
# **********
# running_loss:-------
# 0.007523295823425882
# epoch 369
# **********
# running_loss:-------
# 0.0075143284363166285
# epoch 370
# **********
# running_loss:-------
# 0.007505239500235296
# epoch 371
# **********
# running_loss:-------
# 0.007496026462008069
# epoch 372
# **********
# running_loss:-------
# 0.00748668786838684
# epoch 373
# **********
# running_loss:-------
# 0.007477222530664998
# epoch 374
# **********
# running_loss:-------
# 0.007467628537801607
# epoch 375
# **********
# running_loss:-------
# 0.007457903585000819
# epoch 376
# **********
# running_loss:-------
# 0.00744804650114156
# epoch 377
# **********
# running_loss:-------
# 0.007438054430446017
# epoch 378
# **********
# running_loss:-------
# 0.007427926791501186
# epoch 379
# **********
# running_loss:-------
# 0.007417661601881169
# epoch 380
# **********
# running_loss:-------
# 0.0074072561441224484
# epoch 381
# **********
# running_loss:-------
# 0.007396709326309977
# epoch 382
# **********
# running_loss:-------
# 0.007386018343479145
# epoch 383
# **********
# running_loss:-------
# 0.007375182433242315
# epoch 384
# **********
# running_loss:-------
# 0.0073641994088779715
# epoch 385
# **********
# running_loss:-------
# 0.007353067218755669
# epoch 386
# **********
# running_loss:-------
# 0.00734178340568735
# epoch 387
# **********
# running_loss:-------
# 0.007330345335965961
# epoch 388
# **********
# running_loss:-------
# 0.007318751717931273
# epoch 389
# **********
# running_loss:-------
# 0.007307000955517846
# epoch 390
# **********
# running_loss:-------
# 0.00729509012976317
# epoch 391
# **********
# running_loss:-------
# 0.0072830172635975875
# epoch 392
# **********
# running_loss:-------
# 0.007270780906237811
# epoch 393
# **********
# running_loss:-------
# 0.007258378470855756
# epoch 394
# **********
# running_loss:-------
# 0.0072458077936242895
# epoch 395
# **********
# running_loss:-------
# 0.007233066803384011
# epoch 396
# **********
# running_loss:-------
# 0.007220152589609673
# epoch 397
# **********
# running_loss:-------
# 0.007207063424320594
# epoch 398
# **********
# running_loss:-------
# 0.007193797276221089
# epoch 399
# **********
# running_loss:-------
# 0.007180350993328397
# epoch 400
# **********
# running_loss:-------
# 0.00716672273172052
# epoch 401
# **********
# running_loss:-------
# 0.007152909310216066
# epoch 402
# **********
# running_loss:-------
# 0.007138909654295927
# epoch 403
# **********
# running_loss:-------
# 0.0071247195026663615
# epoch 404
# **********
# running_loss:-------
# 0.007110337421608215
# epoch 405
# **********
# running_loss:-------
# 0.007095760557571493
# epoch 406
# **********
# running_loss:-------
# 0.007080986093030484
# epoch 407
# **********
# running_loss:-------
# 0.007066011203681225
# epoch 408
# **********
# running_loss:-------
# 0.007050832900740449
# epoch 409
# **********
# running_loss:-------
# 0.007035448130770778
# epoch 410
# **********
# running_loss:-------
# 0.007019854699419235
# epoch 411
# **********
# running_loss:-------
# 0.007004048884429147
# epoch 412
# **********
# running_loss:-------
# 0.006988027657674935
# epoch 413
# **********
# running_loss:-------
# 0.006971788194094229
# epoch 414
# **********
# running_loss:-------
# 0.006955327656679765
# epoch 415
# **********
# running_loss:-------
# 0.006938642750062649
# epoch 416
# **********
# running_loss:-------
# 0.006921728551713901
# epoch 417
# **********
# running_loss:-------
# 0.006904582103944902
# epoch 418
# **********
# running_loss:-------
# 0.006887201984649591
# epoch 419
# **********
# running_loss:-------
# 0.006869582244038054
# epoch 420
# **********
# running_loss:-------
# 0.006851718189473133
# epoch 421
# **********
# running_loss:-------
# 0.006833607940771541
# epoch 422
# **********
# running_loss:-------
# 0.00681524629896531
# epoch 423
# **********
# running_loss:-------
# 0.006796629400734246
# epoch 424
# **********
# running_loss:-------
# 0.006777753126037729
# epoch 425
# **********
# running_loss:-------
# 0.0067586125265609726
# epoch 426
# **********
# running_loss:-------
# 0.006739202436516274
# epoch 427
# **********
# running_loss:-------
# 0.006719518046756351
# epoch 428
# **********
# running_loss:-------
# 0.0066995552403690045
# epoch 429
# **********
# running_loss:-------
# 0.006679307299393839
# epoch 430
# **********
# running_loss:-------
# 0.006658770416348305
# epoch 431
# **********
# running_loss:-------
# 0.006637938454116206
# epoch 432
# **********
# running_loss:-------
# 0.006616805563491226
# epoch 433
# **********
# running_loss:-------
# 0.006595366219770017
# epoch 434
# **********
# running_loss:-------
# 0.006573614341294823
# epoch 435
# **********
# running_loss:-------
# 0.006551542855360839
# epoch 436
# **********
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# E:\Anaconda\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# E:\Anaconda\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      85         grad_tensors = list(grad_tensors)
#      86
# ---> 87     grad_tensors = _make_grads(tensors, grad_tensors)
#      88     if retain_graph is None:
#      89         retain_graph = create_graph
#
# E:\Anaconda\lib\site-packages\torch\autograd\__init__.py in _make_grads(outputs, grads)
#      27                 if out.numel() != 1:
#      28                     raise RuntimeError("grad can be implicitly created only for scalar outputs")
# ---> 29                 new_grads.append(torch.ones_like(out))
#      30             else:
#      31                 new_grads.append(None)
#
# KeyboardInterrupt:

# %%
print(train_x.size(),train_y.size(),out.size())
out = model(train_x)
# Out:
# torch.Size([100, 1, 8]) torch.Size([100, 1]) torch.Size([100, 1])

# %%
import matplotlib.pyplot as plt
plt.plot(losslist,'r-.') 
plt.show()

# %% [raw]
# 0.00797845292009054

# %%
out.detach().numpy().shape
# Out:
# (100, 1)

# %%
x=range(0,100)
plt.figure(num=1,figsize=(18,5))#定义编号为1 大小为(8,5)
plt.plot(x,train_y.numpy(),'r-.',label='train_y') 
plt.plot(x,out.detach().numpy(),'b-.',label='out') 
plt.legend(loc='best')#显示在最好的位置
plt.show()

# %%
model.eval()
    
test_x=test_dataset[:,0:8]

test_x=test_x.view(-1,1,8)

test_y=test_dataset[:,8]

test_y=test_y.view(-1,1)

test_x=Variable(test_x)

test_y=Variable(test_y)

out = model(test_x)

# %%
#x=range(0,13123)
x=range(1200,1300)
plt.figure(num=1,figsize=(18,5))#定义编号为1 大小为(8,5)
plt.plot(x,test_y.numpy()[1200:1300],'r-.',label='test_y') 
plt.plot(x,out.detach().numpy()[1200:1300],'b-.',label='out') 
plt.legend(loc='best')#显示在最好的位置
plt.show()

# %%
# 保存模型
torch.save(model.state_dict(), './weatherlstm-0.01-false.pth')
