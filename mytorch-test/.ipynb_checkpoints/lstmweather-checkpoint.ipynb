# %%
import csv

import pandas as pd

import numpy as np

import torch

from torch import nn, optim

from torch.autograd import Variable

from torch.utils.data import Dataset

from torch.utils.data import DataLoader

import time

# %%
# 定义自己的类
class MyDataset(Dataset):
    
    # 初始化
    def __init__(self, file_name):
        # 读入数据
        self.data = pd.read_csv(file_name)
    
    # 返回df的长度
    def __len__(self):
        return len(self.data)
    
    # 获取第idx+1列的数据
    def __getitem__(self, idx):
        return self.data.values[idx,1:10]

# 通过实例化对象来访问该类
# 假设同目录下存在名为median_benchmark.csv的文件
ds = MyDataset('formatweather.csv')
ds=np.asarray(ds[:], dtype = np.float32)#####源文件float32 ,不知道为什么读取变为float64，这里再进行处理  最大最小化时变化
##dl = DataLoader(ds, batch_size=100, shuffle=False)

#####处理为torch，分为trainx，trainy
torchds=torch.from_numpy(ds[:])

# %%
train_dataset =torchds[:30700]  ##0.7*43823
test_dataset =torchds[30700:]
dl = DataLoader(train_dataset, batch_size=100, shuffle=False)

# %%
# 定义 Recurrent Network 模型

class Rnn(nn.Module):

    def __init__(self, in_dim, hidden_dim, n_layer, n_class):

        super(Rnn, self).__init__()

        self.n_layer = n_layer

        self.hidden_dim = hidden_dim

        self.lstm = nn.LSTM(in_dim, hidden_dim, n_layer, batch_first=True)

        self.classifier = nn.Linear(hidden_dim, n_class)



    def forward(self, x):

        # h0 = Variable(torch.zeros(self.n_layer, x.size(1),

        #   self.hidden_dim)).cuda()

        # c0 = Variable(torch.zeros(self.n_layer, x.size(1),

        #   self.hidden_dim)).cuda()

        out, _ = self.lstm(x) #out 100 28 128 _ [0]2 100 128 [1]2 100 128

        out = out[:, -1, :]  #100,128

        out = self.classifier(out) #100,10

        return out

# %%
model = Rnn(8, 4, 2, 1)  
##model.load_state_dict(torch.load('./weathercnn.pth'))
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01) ####速度很快

# %%
# %%time 
losslist=[]
for epoch in range(10000):
 
    print('epoch {}'.format(epoch + 1))

    print('*' * 10)

    running_loss = 0.0

    for i, data in enumerate(dl, 1):
        
            train_x=data[:,0:8]
            
            train_x=train_x.view(-1,1,8)
            
            train_y=data[:,8]
            
            train_y=train_y.view(-1,1)
            
            train_x=Variable(train_x)
            
            train_y=Variable(train_y)
        
            out = model(train_x)

            loss = criterion(out, train_y)
            
            running_loss += loss.item() * train_y.size(0)
            

            # 向后传播

            optimizer.zero_grad()

            loss.backward()

            optimizer.step()
            
    losslist.append(running_loss / (len(train_dataset)))   
           
                
    print('running_loss:-------')
    print(running_loss / (len(train_dataset)))            
    #print(out,train_y)
# Out:
# epoch 1
# **********
# running_loss:-------
# 0.00823943906451406
# epoch 2
# **********
# running_loss:-------
# 0.008209630513598545
# epoch 3
# **********
# running_loss:-------
# 0.008208762089745938
# epoch 4
# **********
# running_loss:-------
# 0.008207866678928087
# epoch 5
# **********
# running_loss:-------
# 0.008206968359718007
# epoch 6
# **********
# running_loss:-------
# 0.008206067384380494
# epoch 7
# **********
# running_loss:-------
# 0.008205163770418137
# epoch 8
# **********
# running_loss:-------
# 0.008204256988487245
# epoch 9
# **********
# running_loss:-------
# 0.008203347257755303
# epoch 10
# **********
# running_loss:-------
# 0.008202434269278514
# epoch 11
# **********
# running_loss:-------
# 0.008201518747666418
# epoch 12
# **********
# running_loss:-------
# 0.008200599697203029
# epoch 13
# **********
# running_loss:-------
# 0.008199677486580315
# epoch 14
# **********
# running_loss:-------
# 0.008198751904108202
# epoch 15
# **********
# running_loss:-------
# 0.00819782294970374
# epoch 16
# **********
# running_loss:-------
# 0.008196890644341592
# epoch 17
# **********
# running_loss:-------
# 0.008195954793869822
# epoch 18
# **********
# running_loss:-------
# 0.00819501516305222
# epoch 19
# **********
# running_loss:-------
# 0.008194072158121847
# epoch 20
# **********
# running_loss:-------
# 0.008193125058830006
# epoch 21
# **********
# running_loss:-------
# 0.008192174317186671
# epoch 22
# **********
# running_loss:-------
# 0.008191219556963216
# epoch 23
# **********
# running_loss:-------
# 0.008190260791336945
# epoch 24
# **********
# running_loss:-------
# 0.008189298096847613
# epoch 25
# **********
# running_loss:-------
# 0.00818833132073566
# epoch 26
# **********
# running_loss:-------
# 0.008187360203555134
# epoch 27
# **********
# running_loss:-------
# 0.00818638489643028
# epoch 28
# **********
# running_loss:-------
# 0.008185405565819367
# epoch 29
# **********
# running_loss:-------
# 0.00818442157110632
# epoch 30
# **********
# running_loss:-------
# 0.008183432959513764
# epoch 31
# **********
# running_loss:-------
# 0.00818243998709853
# epoch 32
# **********
# running_loss:-------
# 0.008181442259074738
# epoch 33
# **********
# running_loss:-------
# 0.008180439615821624
# epoch 34
# **********
# running_loss:-------
# 0.008179432273947055
# epoch 35
# **********
# running_loss:-------
# 0.008178420316520187
# epoch 36
# **********
# running_loss:-------
# 0.00817740301955954
# epoch 37
# **********
# running_loss:-------
# 0.008176380953102025
# epoch 38
# **********
# running_loss:-------
# 0.008175353646544866
# epoch 39
# **********
# running_loss:-------
# 0.008174321101001974
# epoch 40
# **********
# running_loss:-------
# 0.008173283354417346
# epoch 41
# **********
# running_loss:-------
# 0.008172240199355092
# epoch 42
# **********
# running_loss:-------
# 0.008171191637272774
# epoch 43
# **********
# running_loss:-------
# 0.008170137807397143
# epoch 44
# **********
# running_loss:-------
# 0.008169078037673827
# epoch 45
# **********
# running_loss:-------
# 0.008168012540823862
# epoch 46
# **********
# running_loss:-------
# 0.008166941286096253
# epoch 47
# **********
# running_loss:-------
# 0.008165864055911428
# epoch 48
# **********
# running_loss:-------
# 0.008164780894102884
# epoch 49
# **********
# running_loss:-------
# 0.008163692029377431
# epoch 50
# **********
# running_loss:-------
# 0.008162596658180208
# epoch 51
# **********
# running_loss:-------
# 0.008161495224178725
# epoch 52
# **********
# running_loss:-------
# 0.00816038735781596
# epoch 53
# **********
# running_loss:-------
# 0.008159273207763188
# epoch 54
# **********
# running_loss:-------
# 0.0081581526024903
# epoch 55
# **********
# running_loss:-------
# 0.008157025179811029
# epoch 56
# **********
# running_loss:-------
# 0.008155891246761306
# epoch 57
# **********
# running_loss:-------
# 0.008154750545080186
# epoch 58
# **********
# running_loss:-------
# 0.008153602685432837
# epoch 59
# **********
# running_loss:-------
# 0.008152447904761884
# epoch 60
# **********
# running_loss:-------
# 0.00815128603573215
# epoch 61
# **********
# running_loss:-------
# 0.008150117094270166
# epoch 62
# **********
# running_loss:-------
# 0.008148940645015331
# epoch 63
# **********
# running_loss:-------
# 0.008147757101950676
# epoch 64
# **********
# running_loss:-------
# 0.008146565987387064
# epoch 65
# **********
# running_loss:-------
# 0.008145367446855501
# epoch 66
# **********
# running_loss:-------
# 0.008144161015856008
# epoch 67
# **********
# running_loss:-------
# 0.008142947184235914
# epoch 68
# **********
# running_loss:-------
# 0.00814172492680805
# epoch 69
# **********
# running_loss:-------
# 0.008140494975422363
# epoch 70
# **********
# running_loss:-------
# 0.008139256686701705
# epoch 71
# **********
# running_loss:-------
# 0.008138010185913423
# epoch 72
# **********
# running_loss:-------
# 0.008136755409766161
# epoch 73
# **********
# running_loss:-------
# 0.008135492121483198
# epoch 74
# **********
# running_loss:-------
# 0.008134220403493785
# epoch 75
# **********
# running_loss:-------
# 0.008132939952139265
# epoch 76
# **********
# running_loss:-------
# 0.008131650591742002
# epoch 77
# **********
# running_loss:-------
# 0.008130352354226145
# epoch 78
# **********
# running_loss:-------
# 0.008129045004770236
# epoch 79
# **********
# running_loss:-------
# 0.008127728866099729
# epoch 80
# **********
# running_loss:-------
# 0.008126403198306618
# epoch 81
# **********
# running_loss:-------
# 0.008125068209988102
# epoch 82
# **********
# running_loss:-------
# 0.008123723625570251
# epoch 83
# **********
# running_loss:-------
# 0.008122369674352379
# epoch 84
# **********
# running_loss:-------
# 0.008121005555351094
# epoch 85
# **********
# running_loss:-------
# 0.00811963168600965
# epoch 86
# **********
# running_loss:-------
# 0.008118248044346127
# epoch 87
# **********
# running_loss:-------
# 0.008116854103031345
# epoch 88
# **********
# running_loss:-------
# 0.008115449817082352
# epoch 89
# **********
# running_loss:-------
# 0.008114035442271569
# epoch 90
# **********
# running_loss:-------
# 0.008112610542551097
# epoch 91
# **********
# running_loss:-------
# 0.008111174805410258
# epoch 92
# **********
# running_loss:-------
# 0.008109728326894064
# epoch 93
# **********
# running_loss:-------
# 0.008108270869230383
# epoch 94
# **********
# running_loss:-------
# 0.008106802440074376
# epoch 95
# **********
# running_loss:-------
# 0.008105322672594535
# epoch 96
# **********
# running_loss:-------
# 0.008103831578617257
# epoch 97
# **********
# running_loss:-------
# 0.008102328879463886
# epoch 98
# **********
# running_loss:-------
# 0.008100814606833418
# epoch 99
# **********
# running_loss:-------
# 0.00809928833151546
# epoch 100
# **********
# running_loss:-------
# 0.008097750396273973
# epoch 101
# **********
# running_loss:-------
# 0.008096200338836797
# epoch 102
# **********
# running_loss:-------
# 0.008094637907270937
# epoch 103
# **********
# running_loss:-------
# 0.00809306305803915
# epoch 104
# **********
# running_loss:-------
# 0.008091475671633236
# epoch 105
# **********
# running_loss:-------
# 0.008089875709955147
# epoch 106
# **********
# running_loss:-------
# 0.008088262542485087
# epoch 107
# **********
# running_loss:-------
# 0.008086636409353361
# epoch 108
# **********
# running_loss:-------
# 0.008084997113564007
# epoch 109
# **********
# running_loss:-------
# 0.008083344705942078
# epoch 110
# **********
# running_loss:-------
# 0.008081678713254076
# epoch 111
# **********
# running_loss:-------
# 0.008079998694949063
# epoch 112
# **********
# running_loss:-------
# 0.008078304997962237
# epoch 113
# **********
# running_loss:-------
# 0.008076597389534054
# epoch 114
# **********
# running_loss:-------
# 0.008074875342157587
# epoch 115
# **********
# running_loss:-------
# 0.008073138840735817
# epoch 116
# **********
# running_loss:-------
# 0.008071387899500706
# epoch 117
# **********
# running_loss:-------
# 0.008069621996455622
# epoch 118
# **********
# running_loss:-------
# 0.00806784104050889
# epoch 119
# **********
# running_loss:-------
# 0.008066044901700535
# epoch 120
# **********
# running_loss:-------
# 0.00806423376741609
# epoch 121
# **********
# running_loss:-------
# 0.008062406818731119
# epoch 122
# **********
# running_loss:-------
# 0.00806056395163735
# epoch 123
# **********
# running_loss:-------
# 0.008058705411443573
# epoch 124
# **********
# running_loss:-------
# 0.008056830522007136
# epoch 125
# **********
# running_loss:-------
# 0.00805493931996853
# epoch 126
# **********
# running_loss:-------
# 0.008053031813279167
# epoch 127
# **********
# running_loss:-------
# 0.008051107471268143
# epoch 128
# **********
# running_loss:-------
# 0.008049166178894748
# epoch 129
# **********
# running_loss:-------
# 0.008047207432695899
# epoch 130
# **********
# running_loss:-------
# 0.00804523156087179
# epoch 131
# **********
# running_loss:-------
# 0.008043238155956946
# epoch 132
# **********
# running_loss:-------
# 0.00804122681654129
# epoch 133
# **********
# running_loss:-------
# 0.008039197546203547
# epoch 134
# **********
# running_loss:-------
# 0.00803714981554078
# epoch 135
# **********
# running_loss:-------
# 0.008035083655849082
# epoch 136
# **********
# running_loss:-------
# 0.008032998806082738
# epoch 137
# **********
# running_loss:-------
# 0.008030895120414496
# epoch 138
# **********
# running_loss:-------
# 0.008028772136050785
# epoch 139
# **********
# running_loss:-------
# 0.00802662937927226
# epoch 140
# **********
# running_loss:-------
# 0.008024467225158087
# epoch 141
# **********
# running_loss:-------
# 0.008022284989163898
# epoch 142
# **********
# running_loss:-------
# 0.008020082799116653
# epoch 143
# **********
# running_loss:-------
# 0.008017859927527243
# epoch 144
# **********
# running_loss:-------
# 0.008015616743668292
# epoch 145
# **********
# running_loss:-------
# 0.008013352179087939
# epoch 146
# **********
# running_loss:-------
# 0.008011066328503983
# epoch 147
# **********
# running_loss:-------
# 0.008008759174449388
# epoch 148
# **********
# running_loss:-------
# 0.008006430168584761
# epoch 149
# **********
# running_loss:-------
# 0.008004079242179558
# epoch 150
# **********
# running_loss:-------
# 0.008001705935070933
# epoch 151
# **********
# running_loss:-------
# 0.00799930999966303
# epoch 152
# **********
# running_loss:-------
# 0.007996890917194287
# epoch 153
# **********
# running_loss:-------
# 0.007994448737695803
# epoch 154
# **********
# running_loss:-------
# 0.007991982992804467
# epoch 155
# **********
# running_loss:-------
# 0.007989493591381208
# epoch 156
# **********
# running_loss:-------
# 0.007986980240017703
# epoch 157
# **********
# running_loss:-------
# 0.007984442200287207
# epoch 158
# **********
# running_loss:-------
# 0.00798187983143716
# epoch 159
# **********
# running_loss:-------
# 0.007979292317162
# epoch 160
# **********
# running_loss:-------
# 0.007976679563774888
# epoch 161
# **********
# running_loss:-------
# 0.007974041094641346
# epoch 162
# **********
# running_loss:-------
# 0.007971376614765142
# epoch 163
# **********
# running_loss:-------
# 0.007968685926131203
# epoch 164
# **********
# running_loss:-------
# 0.007965968393408603
# epoch 165
# **********
# running_loss:-------
# 0.007963224269952345
# epoch 166
# **********
# running_loss:-------
# 0.0079604521502939
# epoch 167
# **********
# running_loss:-------
# 0.007957652758379202
# epoch 168
# **********
# running_loss:-------
# 0.007954825088324886
# epoch 169
# **********
# running_loss:-------
# 0.007951969016984778
# epoch 170
# **********
# running_loss:-------
# 0.007949084280575785
# epoch 171
# **********
# running_loss:-------
# 0.00794617041694425
# epoch 172
# **********
# running_loss:-------
# 0.007943227209636361
# epoch 173
# **********
# running_loss:-------
# 0.007940254315331196
# epoch 174
# **********
# running_loss:-------
# 0.007937250761064952
# epoch 175
# **********
# running_loss:-------
# 0.007934216517876002
# epoch 176
# **********
# running_loss:-------
# 0.007931151710356228
# epoch 177
# **********
# running_loss:-------
# 0.007928055103678455
# epoch 178
# **********
# running_loss:-------
# 0.007924926882230144
# epoch 179
# **********
# running_loss:-------
# 0.007921766451136581
# epoch 180
# **********
# running_loss:-------
# 0.007918573220997802
# epoch 181
# **********
# running_loss:-------
# 0.00791534674146284
# epoch 182
# **********
# running_loss:-------
# 0.007912087056851045
# epoch 183
# **********
# running_loss:-------
# 0.00790879319744554
# epoch 184
# **********
# running_loss:-------
# 0.007905465105275664
# epoch 185
# **********
# running_loss:-------
# 0.00790210231309222
# epoch 186
# **********
# running_loss:-------
# 0.007898704401235981
# epoch 187
# **********
# running_loss:-------
# 0.00789527076836209
# epoch 188
# **********
# running_loss:-------
# 0.007891801050862264
# epoch 189
# **********
# running_loss:-------
# 0.00788829419493136
# epoch 190
# **********
# running_loss:-------
# 0.007884750555124186
# epoch 191
# **********
# running_loss:-------
# 0.007881169082778536
# epoch 192
# **********
# running_loss:-------
# 0.007877549693237342
# epoch 193
# **********
# running_loss:-------
# 0.007873892046023708
# epoch 194
# **********
# running_loss:-------
# 0.00787019538564675
# epoch 195
# **********
# running_loss:-------
# 0.007866458838825655
# epoch 196
# **********
# running_loss:-------
# 0.007862682228448917
# epoch 197
# **********
# running_loss:-------
# 0.007858865066458576
# epoch 198
# **********
# running_loss:-------
# 0.007855007196622991
# epoch 199
# **********
# running_loss:-------
# 0.007851107456566461
# epoch 200
# **********
# running_loss:-------
# 0.007847165656663782
# epoch 201
# **********
# running_loss:-------
# 0.007843180939110362
# epoch 202
# **********
# running_loss:-------
# 0.007839152695427586
# epoch 203
# **********
# running_loss:-------
# 0.00783508134001323
# epoch 204
# **********
# running_loss:-------
# 0.007830964823986073
# epoch 205
# **********
# running_loss:-------
# 0.007826803729896728
# epoch 206
# **********
# running_loss:-------
# 0.00782259713919702
# epoch 207
# **********
# running_loss:-------
# 0.007818344688752676
# epoch 208
# **********
# running_loss:-------
# 0.007814045373249135
# epoch 209
# **********
# running_loss:-------
# 0.007809698590203924
# epoch 210
# **********
# running_loss:-------
# 0.007805304034074225
# epoch 211
# **********
# running_loss:-------
# 0.007800860903627795
# epoch 212
# **********
# running_loss:-------
# 0.007796368729103211
# epoch 213
# **********
# running_loss:-------
# 0.007791826567304106
# epoch 214
# **********
# running_loss:-------
# 0.0077872341680276
# epoch 215
# **********
# running_loss:-------
# 0.007782590825434703
# epoch 216
# **********
# running_loss:-------
# 0.007777895768984913
# epoch 217
# **********
# running_loss:-------
# 0.007773148100322616
# epoch 218
# **********
# running_loss:-------
# 0.007768347316198028
# epoch 219
# **********
# running_loss:-------
# 0.007763493135598024
# epoch 220
# **********
# running_loss:-------
# 0.007758584622554792
# epoch 221
# **********
# running_loss:-------
# 0.00775362107964291
# epoch 222
# **********
# running_loss:-------
# 0.007748601573454186
# epoch 223
# **********
# running_loss:-------
# 0.007743525544308689
# epoch 224
# **********
# running_loss:-------
# 0.0077383921444981055
# epoch 225
# **********
# running_loss:-------
# 0.007733200922391661
# epoch 226
# **********
# running_loss:-------
# 0.007727951009685579
# epoch 227
# **********
# running_loss:-------
# 0.0077226416551787105
# epoch 228
# **********
# running_loss:-------
# 0.00771727175185899
# epoch 229
# **********
# running_loss:-------
# 0.007711840986220336
# epoch 230
# **********
# running_loss:-------
# 0.00770634835330369
# epoch 231
# **********
# running_loss:-------
# 0.007700793492392196
# epoch 232
# **********
# running_loss:-------
# 0.007695175366578942
# epoch 233
# **********
# running_loss:-------
# 0.0076894928869825074
# epoch 234
# **********
# running_loss:-------
# 0.007683745636858792
# epoch 235
# **********
# running_loss:-------
# 0.007677932733470606
# epoch 236
# **********
# running_loss:-------
# 0.007672053660770062
# epoch 237
# **********
# running_loss:-------
# 0.007666106821720015
# epoch 238
# **********
# running_loss:-------
# 0.007660092330555369
# epoch 239
# **********
# running_loss:-------
# 0.007654008865635159
# epoch 240
# **********
# running_loss:-------
# 0.00764785526823351
# epoch 241
# **********
# running_loss:-------
# 0.007641630981846315
# epoch 242
# **********
# running_loss:-------
# 0.007635335157414351
# epoch 243
# **********
# running_loss:-------
# 0.007628966636472444
# epoch 244
# **********
# running_loss:-------
# 0.0076225248589614596
# epoch 245
# **********
# running_loss:-------
# 0.007616008784087657
# epoch 246
# **********
# running_loss:-------
# 0.007609417121257316
# epoch 247
# **********
# running_loss:-------
# 0.007602749484512881
# epoch 248
# **********
# running_loss:-------
# 0.007596004851523056
# epoch 249
# **********
# running_loss:-------
# 0.007589182109848432
# epoch 250
# **********
# running_loss:-------
# 0.0075822807714784465
# epoch 251
# **********
# running_loss:-------
# 0.007575299391223054
# epoch 252
# **********
# running_loss:-------
# 0.0075682362032286725
# epoch 253
# **********
# running_loss:-------
# 0.007561091306325085
# epoch 254
# **********
# running_loss:-------
# 0.007553864111373025
# epoch 255
# **********
# running_loss:-------
# 0.00754655294077841
# epoch 256
# **********
# running_loss:-------
# 0.007539157165988563
# epoch 257
# **********
# running_loss:-------
# 0.007531675502619212
# epoch 258
# **********
# running_loss:-------
# 0.007524106655621003
# epoch 259
# **********
# running_loss:-------
# 0.00751644992067176
# epoch 260
# **********
# running_loss:-------
# 0.007508704227589508
# epoch 261
# **********
# running_loss:-------
# 0.007500868283410508
# epoch 262
# **********
# running_loss:-------
# 0.007492941294012573
# epoch 263
# **********
# running_loss:-------
# 0.0074849219519274495
# epoch 264
# **********
# running_loss:-------
# 0.0074768095364561304
# epoch 265
# **********
# running_loss:-------
# 0.0074686028895837465
# epoch 266
# **********
# running_loss:-------
# 0.00746030086488482
# epoch 267
# **********
# running_loss:-------
# 0.007451902497264008
# epoch 268
# **********
# running_loss:-------
# 0.007443406045065619
# epoch 269
# **********
# running_loss:-------
# 0.007434811330751549
# epoch 270
# **********
# running_loss:-------
# 0.007426116165277663
# epoch 271
# **********
# running_loss:-------
# 0.0074173197326465
# epoch 272
# **********
# running_loss:-------
# 0.0074084216184839785
# epoch 273
# **********
# running_loss:-------
# 0.0073994195755383045
# epoch 274
# **********
# running_loss:-------
# 0.0073903123504961525
# epoch 275
# **********
# running_loss:-------
# 0.00738109942399161
# epoch 276
# **********
# running_loss:-------
# 0.007371779548162398
# epoch 277
# **********
# running_loss:-------
# 0.0073623519726605715
# epoch 278
# **********
# running_loss:-------
# 0.007352814445115098
# epoch 279
# **********
# running_loss:-------
# 0.0073431664146388145
# epoch 280
# **********
# running_loss:-------
# 0.007333406189844127
# epoch 281
# **********
# running_loss:-------
# 0.007323532541165302
# epoch 282
# **********
# running_loss:-------
# 0.0073135442462888564
# epoch 283
# **********
# running_loss:-------
# 0.007303440043227201
# epoch 284
# **********
# running_loss:-------
# 0.007293218169492178
# epoch 285
# **********
# running_loss:-------
# 0.0072828780650483526
# epoch 286
# **********
# running_loss:-------
# 0.007272418087520121
# epoch 287
# **********
# running_loss:-------
# 0.007261837076688495
# epoch 288
# **********
# running_loss:-------
# 0.007251133855933957
# epoch 289
# **********
# running_loss:-------
# 0.007240306181938946
# epoch 290
# **********
# running_loss:-------
# 0.007229352607807002
# epoch 291
# **********
# running_loss:-------
# 0.0072182718768119755
# epoch 292
# **********
# running_loss:-------
# 0.007207062655107304
# epoch 293
# **********
# running_loss:-------
# 0.007195723441286097
# epoch 294
# **********
# running_loss:-------
# 0.00718425351955529
# epoch 295
# **********
# running_loss:-------
# 0.007172650561418842
# epoch 296
# **********
# running_loss:-------
# 0.007160913267964269
# epoch 297
# **********
# running_loss:-------
# 0.007149039565993955
# epoch 298
# **********
# running_loss:-------
# 0.00713702751455733
# epoch 299
# **********
# running_loss:-------
# 0.007124876173183546
# epoch 300
# **********
# running_loss:-------
# 0.007112584512573454
# epoch 301
# **********
# running_loss:-------
# 0.007100149975856008
# epoch 302
# **********
# running_loss:-------
# 0.007087570666826591
# epoch 303
# **********
# running_loss:-------
# 0.007074845335632108
# epoch 304
# **********
# running_loss:-------
# 0.0070619721639467595
# epoch 305
# **********
# running_loss:-------
# 0.007048948499340343
# epoch 306
# **********
# running_loss:-------
# 0.007035773628342408
# epoch 307
# **********
# running_loss:-------
# 0.007022444374985608
# epoch 308
# **********
# running_loss:-------
# 0.0070089588108804704
# epoch 309
# **********
# running_loss:-------
# 0.006995315620998385
# epoch 310
# **********
# running_loss:-------
# 0.00698151219372087
# epoch 311
# **********
# running_loss:-------
# 0.006967546593880202
# epoch 312
# **********
# running_loss:-------
# 0.006953416651013195
# epoch 313
# **********
# running_loss:-------
# 0.006939119720084104
# epoch 314
# **********
# running_loss:-------
# 0.00692465329048465
# epoch 315
# **********
# running_loss:-------
# 0.006910015691019798
# epoch 316
# **********
# running_loss:-------
# 0.006895203792980375
# epoch 317
# **********
# running_loss:-------
# 0.006880214397836452
# epoch 318
# **********
# running_loss:-------
# 0.00686504536114765
# epoch 319
# **********
# running_loss:-------
# 0.006849694710821353
# epoch 320
# **********
# running_loss:-------
# 0.006834158557846365
# epoch 321
# **********
# running_loss:-------
# 0.006818433965864236
# epoch 322
# **********
# running_loss:-------
# 0.00680251850062869
# epoch 323
# **********
# running_loss:-------
# 0.006786408013658877
# epoch 324
# **********
# running_loss:-------
# 0.006770098851618269
# epoch 325
# **********
# running_loss:-------
# 0.006753589824378242
# epoch 326
# **********
# running_loss:-------
# 0.006736875930819994
# epoch 327
# **********
# running_loss:-------
# 0.006719952783469985
# epoch 328
# **********
# running_loss:-------
# 0.006702816989598947
# epoch 329
# **********
# running_loss:-------
# 0.006685465205489606
# epoch 330
# **********
# running_loss:-------
# 0.006667893174114252
# epoch 331
# **********
# running_loss:-------
# 0.0066500963119513895
# epoch 332
# **********
# running_loss:-------
# 0.006632069924183445
# epoch 333
# **********
# running_loss:-------
# 0.006613809517823639
# epoch 334
# **********
# running_loss:-------
# 0.006595309992022782
# epoch 335
# **********
# running_loss:-------
# 0.006576566418374248
# epoch 336
# **********
# running_loss:-------
# 0.006557574208521706
# epoch 337
# **********
# running_loss:-------
# 0.006538327455240778
# epoch 338
# **********
# running_loss:-------
# 0.006518819067150913
# epoch 339
# **********
# running_loss:-------
# 0.006499044827325118
# epoch 340
# **********
# running_loss:-------
# 0.0064789969938600905
# epoch 341
# **********
# running_loss:-------
# 0.006458670880754724
# epoch 342
# **********
# running_loss:-------
# 0.0064380584128810765
# epoch 343
# **********
# running_loss:-------
# 0.0064171537681458465
# epoch 344
# **********
# running_loss:-------
# 0.00639594982976188
# epoch 345
# **********
# running_loss:-------
# 0.006374437363188053
# epoch 346
# **********
# running_loss:-------
# 0.00635261073782858
# epoch 347
# **********
# running_loss:-------
# 0.006330460061604333
# epoch 348
# **********
# running_loss:-------
# 0.006307977956078085
# epoch 349
# **********
# running_loss:-------
# 0.006285155171635394
# epoch 350
# **********
# running_loss:-------
# 0.0062619818150595205
# epoch 351
# **********
# running_loss:-------
# 0.006238449831794286
# epoch 352
# **********
# running_loss:-------
# 0.006214548974068143
# epoch 353
# **********
# running_loss:-------
# 0.006190268290308774
# epoch 354
# **********
# running_loss:-------
# 0.006165597892987484
# epoch 355
# **********
# running_loss:-------
# 0.006140527121380657
# epoch 356
# **********
# running_loss:-------
# 0.006115043987838569
# epoch 357
# **********
# running_loss:-------
# 0.006089136763138344
# epoch 358
# **********
# running_loss:-------
# 0.006062793575192374
# epoch 359
# **********
# running_loss:-------
# 0.006036001482276179
# epoch 360
# **********
# running_loss:-------
# 0.0060087480360083885
# epoch 361
# **********
# running_loss:-------
# 0.005981019773449997
# epoch 362
# **********
# running_loss:-------
# 0.005952802359969097
# epoch 363
# **********
# running_loss:-------
# 0.005924082525735812
# epoch 364
# **********
# running_loss:-------
# 0.005894846008261605
# epoch 365
# **********
# running_loss:-------
# 0.005865076461811444
# epoch 366
# **********
# running_loss:-------
# 0.0058347594167571515
# epoch 367
# **********
# running_loss:-------
# 0.005803877952302342
# epoch 368
# **********
# running_loss:-------
# 0.00577241750051046
# epoch 369
# **********
# running_loss:-------
# 0.005740360488735157
# epoch 370
# **********
# running_loss:-------
# 0.005707689674805504
# epoch 371
# **********
# running_loss:-------
# 0.00567438820333763
# epoch 372
# **********
# running_loss:-------
# 0.005640438114518925
# epoch 373
# **********
# running_loss:-------
# 0.00560582223889063
# epoch 374
# **********
# running_loss:-------
# 0.005570522271565401
# epoch 375
# **********
# running_loss:-------
# 0.005534519901019839
# epoch 376
# **********
# running_loss:-------
# 0.005497795842695641
# epoch 377
# **********
# running_loss:-------
# 0.005460332736679343
# epoch 378
# **********
# running_loss:-------
# 0.0054221127192862935
# epoch 379
# **********
# running_loss:-------
# 0.005383117274792276
# epoch 380
# **********
# running_loss:-------
# 0.00534332748381148
# epoch 381
# **********
# running_loss:-------
# 0.005302723474020945
# epoch 382
# **********
# running_loss:-------
# 0.005261288522378654
# epoch 383
# **********
# running_loss:-------
# 0.005219005075008805
# epoch 384
# **********
# running_loss:-------
# 0.005175856573253882
# epoch 385
# **********
# running_loss:-------
# 0.005131826677256497
# epoch 386
# **********
# running_loss:-------
# 0.005086899566667379
# epoch 387
# **********
# running_loss:-------
# 0.005041059660983153
# epoch 388
# **********
# running_loss:-------
# 0.0049942928788795195
# epoch 389
# **********
# running_loss:-------
# 0.004946584832067343
# epoch 390
# **********
# running_loss:-------
# 0.004897925978092665
# epoch 391
# **********
# running_loss:-------
# 0.004848305200809061
# epoch 392
# **********
# running_loss:-------
# 0.004797717505923385
# epoch 393
# **********
# running_loss:-------
# 0.0047461525946612855
# epoch 394
# **********
# running_loss:-------
# 0.004693604398068307
# epoch 395
# **********
# running_loss:-------
# 0.004640072520256516
# epoch 396
# **********
# running_loss:-------
# 0.00458555697127479
# epoch 397
# **********
# running_loss:-------
# 0.004530057904321142
# epoch 398
# **********
# running_loss:-------
# 0.004473583873077705
# epoch 399
# **********
# running_loss:-------
# 0.004416139351571106
# epoch 400
# **********
# running_loss:-------
# 0.004357738083255771
# epoch 401
# **********
# running_loss:-------
# 0.004298393468976215
# epoch 402
# **********
# running_loss:-------
# 0.004238121498016646
# epoch 403
# **********
# running_loss:-------
# 0.00417694525113663
# epoch 404
# **********
# running_loss:-------
# 0.0041148892261773495
# epoch 405
# **********
# running_loss:-------
# 0.0040519840168578595
# epoch 406
# **********
# running_loss:-------
# 0.0039882638286162135
# epoch 407
# **********
# running_loss:-------
# 0.003923767095193546
# epoch 408
# **********
# running_loss:-------
# 0.003858535800429504
# epoch 409
# **********
# running_loss:-------
# 0.003792614475459904
# epoch 410
# **********
# running_loss:-------
# 0.0037260555947754618
# epoch 411
# **********
# running_loss:-------
# 0.003658914330517054
# epoch 412
# **********
# running_loss:-------
# 0.003591251165753212
# epoch 413
# **********
# running_loss:-------
# 0.003523135515963598
# epoch 414
# **********
# running_loss:-------
# 0.0034546309441983313
# epoch 415
# **********
# running_loss:-------
# 0.0033858136781294156
# epoch 416
# **********
# running_loss:-------
# 0.003316762606391125
# epoch 417
# **********
# running_loss:-------
# 0.0032475572158104714
# epoch 418
# **********
# running_loss:-------
# 0.00317828619011969
# epoch 419
# **********
# running_loss:-------
# 0.003109037845413707
# epoch 420
# **********
# running_loss:-------
# 0.003039901522109558
# epoch 421
# **********
# running_loss:-------
# 0.0029709753514030883
# epoch 422
# **********
# running_loss:-------
# 0.0029023545330613305
# epoch 423
# **********
# running_loss:-------
# 0.0028341379172490237
# epoch 424
# **********
# running_loss:-------
# 0.0027664222983766274
# epoch 425
# **********
# running_loss:-------
# 0.0026993138614377606
# epoch 426
# **********
# running_loss:-------
# 0.0026329090883796093
# epoch 427
# **********
# running_loss:-------
# 0.0025673047264018595
# epoch 428
# **********
# running_loss:-------
# 0.002502602216858168
# epoch 429
# **********
# running_loss:-------
# 0.002438891800109097
# epoch 430
# **********
# running_loss:-------
# 0.0023762678525771595
# epoch 431
# **********
# running_loss:-------
# 0.002314817619488001
# epoch 432
# **********
# running_loss:-------
# 0.0022546219432245675
# epoch 433
# **********
# running_loss:-------
# 0.0021957614890820002
# epoch 434
# **********
# running_loss:-------
# 0.0021383079174217383
# epoch 435
# **********
# running_loss:-------
# 0.0020823250221337288
# epoch 436
# **********
# running_loss:-------
# 0.0020278729915509685
# epoch 437
# **********
# running_loss:-------
# 0.0019750039166003368
# epoch 438
# **********
# running_loss:-------
# 0.0019237566139232002
# epoch 439
# **********
# running_loss:-------
# 0.001874170924340836
# epoch 440
# **********
# running_loss:-------
# 0.0018262745889703097
# epoch 441
# **********
# running_loss:-------
# 0.0017800850631894411
# epoch 442
# **********
# running_loss:-------
# 0.0017356132168523022
# epoch 443
# **********
# running_loss:-------
# 0.001692862519618967
# epoch 444
# **********
# running_loss:-------
# 0.0016518297121448273
# epoch 445
# **********
# running_loss:-------
# 0.0016125042660007137
# epoch 446
# **********
# running_loss:-------
# 0.0015748669824230026
# epoch 447
# **********
# running_loss:-------
# 0.0015388914976073337
# epoch 448
# **********
# running_loss:-------
# 0.001504551096891769
# epoch 449
# **********
# running_loss:-------
# 0.001471805121845957
# epoch 450
# **********
# running_loss:-------
# 0.0014406143615048087
# epoch 451
# **********
# running_loss:-------
# 0.0014109337675944121
# epoch 452
# **********
# running_loss:-------
# 0.0013827139731926589
# epoch 453
# **********
# running_loss:-------
# 0.001355904898997199
# epoch 454
# **********
# running_loss:-------
# 0.0013304505848833162
# epoch 455
# **********
# running_loss:-------
# 0.0013062974122100349
# epoch 456
# **********
# running_loss:-------
# 0.0012833887017889446
# epoch 457
# **********
# running_loss:-------
# 0.0012616673871705686
# epoch 458
# **********
# running_loss:-------
# 0.001241077504058957
# epoch 459
# **********
# running_loss:-------
# 0.001221560853277864
# epoch 460
# **********
# running_loss:-------
# 0.001203060957706679
# epoch 461
# **********
# running_loss:-------
# 0.0011855241273194613
# epoch 462
# **********
# running_loss:-------
# 0.001168897403193659
# epoch 463
# **********
# running_loss:-------
# 0.0011531257773832954
# epoch 464
# **********
# running_loss:-------
# 0.0011381606093770142
# epoch 465
# **********
# running_loss:-------
# 0.0011239540623842225
# epoch 466
# **********
# running_loss:-------
# 0.0011104599462085668
# epoch 467
# **********
# running_loss:-------
# 0.001097636201074999
# epoch 468
# **********
# running_loss:-------
# 0.0010854392117177552
# epoch 469
# **********
# running_loss:-------
# 0.0010738291090649343
# epoch 470
# **********
# running_loss:-------
# 0.001062770543623024
# epoch 471
# **********
# running_loss:-------
# 0.0010522274044588822
# epoch 472
# **********
# running_loss:-------
# 0.001042166502730305
# epoch 473
# **********
# running_loss:-------
# 0.001032558932219001
# epoch 474
# **********
# running_loss:-------
# 0.0010233751769956499
# epoch 475
# **********
# running_loss:-------
# 0.0010145892424100148
# epoch 476
# **********
# running_loss:-------
# 0.0010061766145995845
# epoch 477
# **********
# running_loss:-------
# 0.0009981138912406491
# epoch 478
# **********
# running_loss:-------
# 0.0009903790161327583
# epoch 479
# **********
# running_loss:-------
# 0.0009829538121325773
# epoch 480
# **********
# running_loss:-------
# 0.0009758193252994209
# epoch 481
# **********
# running_loss:-------
# 0.0009689585167625676
# epoch 482
# **********
# running_loss:-------
# 0.0009623565834322004
# epoch 483
# **********
# running_loss:-------
# 0.0009559983601270346
# epoch 484
# **********
# running_loss:-------
# 0.0009498701387059235
# epoch 485
# **********
# running_loss:-------
# 0.000943960439651167
# epoch 486
# **********
# running_loss:-------
# 0.0009382573782192568
# epoch 487
# **********
# running_loss:-------
# 0.000932750825044784
# epoch 488
# **********
# running_loss:-------
# 0.0009274304869940432
# epoch 489
# **********
# running_loss:-------
# 0.0009222871136941859
# epoch 490
# **********
# running_loss:-------
# 0.0009173127544906555
# epoch 491
# **********
# running_loss:-------
# 0.0009124992292636781
# epoch 492
# **********
# running_loss:-------
# 0.0009078400469584548
# epoch 493
# **********
# running_loss:-------
# 0.0009033276415270744
# epoch 494
# **********
# running_loss:-------
# 0.0008989555459467281
# epoch 495
# **********
# running_loss:-------
# 0.0008947180332092671
# epoch 496
# **********
# running_loss:-------
# 0.0008906092444386982
# epoch 497
# **********
# running_loss:-------
# 0.0008866250846217954
# epoch 498
# **********
# running_loss:-------
# 0.0008827594736176133
# epoch 499
# **********
# running_loss:-------
# 0.0008790081612714976
# epoch 500
# **********
# running_loss:-------
# 0.0008753671041181302
# epoch 501
# **********
# running_loss:-------
# 0.0008718317897602801
# epoch 502
# **********
# running_loss:-------
# 0.0008683988897909914
# epoch 503
# **********
# running_loss:-------
# 0.0008650642398976894
# epoch 504
# **********
# running_loss:-------
# 0.0008618243363394299
# epoch 505
# **********
# running_loss:-------
# 0.0008586754906797062
# epoch 506
# **********
# running_loss:-------
# 0.0008556151242432995
# epoch 507
# **********
# running_loss:-------
# 0.0008526401984054483
# epoch 508
# **********
# running_loss:-------
# 0.0008497477396695074
# epoch 509
# **********
# running_loss:-------
# 0.0008469352342513715
# epoch 510
# **********
# running_loss:-------
# 0.0008441998602407954
# epoch 511
# **********
# running_loss:-------
# 0.0008415384928154356
# epoch 512
# **********
# running_loss:-------
# 0.0008389493332021485
# epoch 513
# **********
# running_loss:-------
# 0.0008364296972361797
# epoch 514
# **********
# running_loss:-------
# 0.000833977356151881
# epoch 515
# **********
# running_loss:-------
# 0.0008315899034558966
# epoch 516
# **********
# running_loss:-------
# 0.0008292658384523433
# epoch 517
# **********
# running_loss:-------
# 0.0008270027818793813
# epoch 518
# **********
# running_loss:-------
# 0.0008247989475249664
# epoch 519
# **********
# running_loss:-------
# 0.0008226526110345446
# epoch 520
# **********
# running_loss:-------
# 0.0008205621304117137
# epoch 521
# **********
# running_loss:-------
# 0.0008185255438734395
# epoch 522
# **********
# running_loss:-------
# 0.0008165408664105038
# epoch 523
# **********
# running_loss:-------
# 0.0008146066320714987
# epoch 524
# **********
# running_loss:-------
# 0.000812721359499894
# epoch 525
# **********
# running_loss:-------
# 0.00081088338804724
# epoch 526
# **********
# running_loss:-------
# 0.0008090917505799787
# epoch 527
# **********
# running_loss:-------
# 0.0008073445307246351
# epoch 528
# **********
# running_loss:-------
# 0.0008056403734940802
# epoch 529
# **********
# running_loss:-------
# 0.0008039781889640832
# epoch 530
# **********
# running_loss:-------
# 0.0008023568020793397
# epoch 531
# **********
# running_loss:-------
# 0.0008007748535866864
# epoch 532
# **********
# running_loss:-------
# 0.0007992310931116224
# epoch 533
# **********
# running_loss:-------
# 0.0007977245138227751
# epoch 534
# **********
# running_loss:-------
# 0.0007962538269987399
# epoch 535
# **********
# running_loss:-------
# 0.0007948179536173726
# epoch 536
# **********
# running_loss:-------
# 0.000793415969205453
# epoch 537
# **********
# running_loss:-------
# 0.000792047114432668
# epoch 538
# **********
# running_loss:-------
# 0.0007907101323832652
# epoch 539
# **********
# running_loss:-------
# 0.000789404161365821
# epoch 540
# **********
# running_loss:-------
# 0.000788128269038653
# epoch 541
# **********
# running_loss:-------
# 0.0007868817193213326
# epoch 542
# **********
# running_loss:-------
# 0.0007856631865201621
# epoch 543
# **********
# running_loss:-------
# 0.0007844721917254496
# epoch 544
# **********
# running_loss:-------
# 0.0007833083735330331
# epoch 545
# **********
# running_loss:-------
# 0.0007821702487851685
# epoch 546
# **********
# running_loss:-------
# 0.0007810572994668537
# epoch 547
# **********
# running_loss:-------
# 0.0007799687230186339
# epoch 548
# **********
# running_loss:-------
# 0.0007789040834992572
# epoch 549
# **********
# running_loss:-------
# 0.0007778626827959955
# epoch 550
# **********
# running_loss:-------
# 0.000776843689221863
# epoch 551
# **********
# running_loss:-------
# 0.0007758467693389196
# epoch 552
# **********
# running_loss:-------
# 0.0007748708455707326
# epoch 553
# **********
# running_loss:-------
# 0.0007739154445060532
# epoch 554
# **********
# running_loss:-------
# 0.0007729801462012561
# epoch 555
# **********
# running_loss:-------
# 0.0007720646397809799
# epoch 556
# **********
# running_loss:-------
# 0.0007711680600461732
# epoch 557
# **********
# running_loss:-------
# 0.0007702899099091002
# epoch 558
# **********
# running_loss:-------
# 0.0007694299115561607
# epoch 559
# **********
# running_loss:-------
# 0.0007685871737180976
# epoch 560
# **********
# running_loss:-------
# 0.0007677614909142836
# epoch 561
# **********
# running_loss:-------
# 0.0007669525255829457
# epoch 562
# **********
# running_loss:-------
# 0.0007661595487537117
# epoch 563
# **********
# running_loss:-------
# 0.0007653824336542778
# epoch 564
# **********
# running_loss:-------
# 0.0007646206076051593
# epoch 565
# **********
# running_loss:-------
# 0.0007638736616596178
# epoch 566
# **********
# running_loss:-------
# 0.0007631411526122938
# epoch 567
# **********
# running_loss:-------
# 0.0007624227534479982
# epoch 568
# **********
# running_loss:-------
# 0.000761718060967288
# epoch 569
# **********
# running_loss:-------
# 0.0007610268735408165
# epoch 570
# **********
# running_loss:-------
# 0.000760348849174876
# epoch 571
# **********
# running_loss:-------
# 0.0007596835120170982
# epoch 572
# **********
# running_loss:-------
# 0.0007590306104425908
# epoch 573
# **********
# running_loss:-------
# 0.0007583898951016792
# epoch 574
# **********
# running_loss:-------
# 0.0007577610655233844
# epoch 575
# **********
# running_loss:-------
# 0.0007571435629046811
# epoch 576
# **********
# running_loss:-------
# 0.0007565375366160026
# epoch 577
# **********
# running_loss:-------
# 0.0007559423527721291
# epoch 578
# **********
# running_loss:-------
# 0.0007553577499244406
# epoch 579
# **********
# running_loss:-------
# 0.0007547836670331036
# epoch 580
# **********
# running_loss:-------
# 0.0007542197527665363
# epoch 581
# **********
# running_loss:-------
# 0.0007536658259131036
# epoch 582
# **********
# running_loss:-------
# 0.0007531216157929621
# epoch 583
# **********
# running_loss:-------
# 0.0007525867779357344
# epoch 584
# **********
# running_loss:-------
# 0.000752061188922693
# epoch 585
# **********
# running_loss:-------
# 0.0007515446659424403
# epoch 586
# **********
# running_loss:-------
# 0.0007510369372723248
# epoch 587
# **********
# running_loss:-------
# 0.000750537733737465
# epoch 588
# **********
# running_loss:-------
# 0.0007500471466191337
# epoch 589
# **********
# running_loss:-------
# 0.0007495648155204272
# epoch 590
# **********
# running_loss:-------
# 0.0007490905156806157
# epoch 591
# **********
# running_loss:-------
# 0.0007486240990920272
# epoch 592
# **********
# running_loss:-------
# 0.0007481652882373141
# epoch 593
# **********
# running_loss:-------
# 0.0007477139350732543
# epoch 594
# **********
# running_loss:-------
# 0.0007472700463188508
# epoch 595
# **********
# running_loss:-------
# 0.0007468333125918541
# epoch 596
# **********
# running_loss:-------
# 0.000746403722919077
# epoch 597
# **********
# running_loss:-------
# 0.0007459809196528376
# epoch 598
# **********
# running_loss:-------
# 0.0007455647854179566
# epoch 599
# **********
# running_loss:-------
# 0.0007451553015031356
# epoch 600
# **********
# running_loss:-------
# 0.0007447522458731666
# epoch 601
# **********
# running_loss:-------
# 0.0007443556368008942
# epoch 602
# **********
# running_loss:-------
# 0.0007439651664564309
# epoch 603
# **********
# running_loss:-------
# 0.0007435807595442804
# epoch 604
# **********
# running_loss:-------
# 0.0007432022533271043
# epoch 605
# **********
# running_loss:-------
# 0.0007428295438321791
# epoch 606
# **********
# running_loss:-------
# 0.0007424624779207423
# epoch 607
# **********
# running_loss:-------
# 0.0007421009519755732
# epoch 608
# **********
# running_loss:-------
# 0.0007417449283252238
# epoch 609
# **********
# running_loss:-------
# 0.0007413941954336689
# epoch 610
# **********
# running_loss:-------
# 0.0007410487148710542
# epoch 611
# **********
# running_loss:-------
# 0.0007407083474580276
# epoch 612
# **********
# running_loss:-------
# 0.0007403730072932589
# epoch 613
# **********
# running_loss:-------
# 0.0007400425513579657
# epoch 614
# **********
# running_loss:-------
# 0.0007397169363993055
# epoch 615
# **********
# running_loss:-------
# 0.0007393961301139224
# epoch 616
# **********
# running_loss:-------
# 0.0007390800280787895
# epoch 617
# **********
# running_loss:-------
# 0.0007387684246355286
# epoch 618
# **********
# running_loss:-------
# 0.0007384612873504326
# epoch 619
# **********
# running_loss:-------
# 0.0007381585267434429
# epoch 620
# **********
# running_loss:-------
# 0.0007378599722561592
# epoch 621
# **********
# running_loss:-------
# 0.0007375656631834925
# epoch 622
# **********
# running_loss:-------
# 0.000737275475786763
# epoch 623
# **********
# running_loss:-------
# 0.0007369893859628799
# epoch 624
# **********
# running_loss:-------
# 0.0007367072684445012
# epoch 625
# **********
# running_loss:-------
# 0.0007364291240966838
# epoch 626
# **********
# running_loss:-------
# 0.0007361547296399596
# epoch 627
# **********
# running_loss:-------
# 0.0007358840925161877
# epoch 628
# **********
# running_loss:-------
# 0.0007356171978772003
# epoch 629
# **********
# running_loss:-------
# 0.0007353539376382918
# epoch 630
# **********
# running_loss:-------
# 0.0007350941623697787
# epoch 631
# **********
# running_loss:-------
# 0.0007348379438121292
# epoch 632
# **********
# running_loss:-------
# 0.0007345851946420018
# epoch 633
# **********
# running_loss:-------
# 0.0007343357875182882
# epoch 634
# **********
# running_loss:-------
# 0.0007340896506412698
# epoch 635
# **********
# running_loss:-------
# 0.0007338467990131654
# epoch 636
# **********
# running_loss:-------
# 0.0007336070955876399
# epoch 637
# **********
# running_loss:-------
# 0.0007333705661741976
# epoch 638
# **********
# running_loss:-------
# 0.0007331370792604971
# epoch 639
# **********
# running_loss:-------
# 0.0007329065869958595
# epoch 640
# **********
# running_loss:-------
# 0.0007326790741529142
# epoch 641
# **********
# running_loss:-------
# 0.0007324544994696347
# epoch 642
# **********
# running_loss:-------
# 0.0007322328446139255
# epoch 643
# **********
# running_loss:-------
# 0.00073201402409921
# epoch 644
# **********
# running_loss:-------
# 0.0007317980026596086
# epoch 645
# **********
# running_loss:-------
# 0.0007315846654795625
# epoch 646
# **********
# running_loss:-------
# 0.0007313739157912051
# epoch 647
# **********
# running_loss:-------
# 0.0007311659387404028
# epoch 648
# **********
# running_loss:-------
# 0.0007309605305292416
# epoch 649
# **********
# running_loss:-------
# 0.0007307576872531157
# epoch 650
# **********
# running_loss:-------
# 0.0007305573290305426
# epoch 651
# **********
# running_loss:-------
# 0.0007303594177930957
# epoch 652
# **********
# running_loss:-------
# 0.000730163982075801
# epoch 653
# **********
# running_loss:-------
# 0.0007299708527718945
# epoch 654
# **********
# running_loss:-------
# 0.0007297799969499655
# epoch 655
# **********
# running_loss:-------
# 0.000729591564661827
# epoch 656
# **********
# running_loss:-------
# 0.0007294053142248154
# epoch 657
# **********
# running_loss:-------
# 0.0007292214327933876
# epoch 658
# **********
# running_loss:-------
# 0.0007290396830160891
# epoch 659
# **********
# running_loss:-------
# 0.0007288601517896581
# epoch 660
# **********
# running_loss:-------
# 0.0007286827197540244
# epoch 661
# **********
# running_loss:-------
# 0.0007285073678483121
# epoch 662
# **********
# running_loss:-------
# 0.0007283340747956777
# epoch 663
# **********
# running_loss:-------
# 0.0007281628352221036
# epoch 664
# **********
# running_loss:-------
# 0.0007279936001333768
# epoch 665
# **********
# running_loss:-------
# 0.0007278262903649456
# epoch 666
# **********
# running_loss:-------
# 0.0007276609269507264
# epoch 667
# **********
# running_loss:-------
# 0.0007274975077636276
# epoch 668
# **********
# running_loss:-------
# 0.0007273359389746059
# epoch 669
# **********
# running_loss:-------
# 0.0007271762063220736
# epoch 670
# **********
# running_loss:-------
# 0.0007270182539743135
# epoch 671
# **********
# running_loss:-------
# 0.0007268620810484936
# epoch 672
# **********
# running_loss:-------
# 0.0007267077243628556
# epoch 673
# **********
# running_loss:-------
# 0.000726555082350245
# epoch 674
# **********
# running_loss:-------
# 0.0007264040745485248
# epoch 675
# **********
# running_loss:-------
# 0.000726254795906572
# epoch 676
# **********
# running_loss:-------
# 0.0007261071462733181
# epoch 677
# **********
# running_loss:-------
# 0.0007259611194807899
# epoch 678
# **********
# running_loss:-------
# 0.0007258166976294201
# epoch 679
# **********
# running_loss:-------
# 0.0007256738462235857
# epoch 680
# **********
# running_loss:-------
# 0.0007255325722844675
# epoch 681
# **********
# running_loss:-------
# 0.0007253927885894497
# epoch 682
# **********
# running_loss:-------
# 0.0007252546635935412
# epoch 683
# **********
# running_loss:-------
# 0.000725117914672004
# epoch 684
# **********
# running_loss:-------
# 0.0007249826661145473
# epoch 685
# **********
# running_loss:-------
# 0.0007248487965110348
# epoch 686
# **********
# running_loss:-------
# 0.0007247163438350922
# epoch 687
# **********
# running_loss:-------
# 0.0007245853588288212
# epoch 688
# **********
# running_loss:-------
# 0.0007244556694644096
# epoch 689
# **********
# running_loss:-------
# 0.0007243274301841305
# epoch 690
# **********
# running_loss:-------
# 0.0007242004385765309
# epoch 691
# **********
# running_loss:-------
# 0.0007240748138476299
# epoch 692
# **********
# running_loss:-------
# 0.0007239504327683017
# epoch 693
# **********
# running_loss:-------
# 0.0007238273532262545
# epoch 694
# **********
# running_loss:-------
# 0.000723705525385919
# epoch 695
# **********
# running_loss:-------
# 0.0007235849264477143
# epoch 696
# **********
# running_loss:-------
# 0.0007234655766930763
# epoch 697
# **********
# running_loss:-------
# 0.000723347411491593
# epoch 698
# **********
# running_loss:-------
# 0.0007232304315601953
# epoch 699
# **********
# running_loss:-------
# 0.0007231146140045017
# epoch 700
# **********
# running_loss:-------
# 0.0007229999753731684
# epoch 701
# **********
# running_loss:-------
# 0.0007228864732547095
# epoch 702
# **********
# running_loss:-------
# 0.0007227740663159976
# epoch 703
# **********
# running_loss:-------
# 0.0007226627800288096
# epoch 704
# **********
# running_loss:-------
# 0.0007225525702219206
# epoch 705
# **********
# running_loss:-------
# 0.0007224434721138095
# epoch 706
# **********
# running_loss:-------
# 0.0007223354114577134
# epoch 707
# **********
# running_loss:-------
# 0.0007222284011465345
# epoch 708
# **********
# running_loss:-------
# 0.000722122416733529
# epoch 709
# **********
# running_loss:-------
# 0.0007220174998777019
# epoch 710
# **********
# running_loss:-------
# 0.0007219134459812581
# epoch 711
# **********
# running_loss:-------
# 0.0007218105050811774
# epoch 712
# **********
# running_loss:-------
# 0.0007217085671671139
# epoch 713
# **********
# running_loss:-------
# 0.0007216075121324414
# epoch 714
# **********
# running_loss:-------
# 0.0007215073846520136
# epoch 715
# **********
# running_loss:-------
# 0.0007214082647732145
# epoch 716
# **********
# running_loss:-------
# 0.000721310021155529
# epoch 717
# **********
# running_loss:-------
# 0.0007212127039011538
# epoch 718
# **********
# running_loss:-------
# 0.0007211163031389608
# epoch 719
# **********
# running_loss:-------
# 0.00072102071215293
# epoch 720
# **********
# running_loss:-------
# 0.0007209260342225541
# epoch 721
# **********
# running_loss:-------
# 0.0007208321731902469
# epoch 722
# **********
# running_loss:-------
# 0.0007207391939945223
# epoch 723
# **********
# running_loss:-------
# 0.000720647019787522
# epoch 724
# **********
# running_loss:-------
# 0.0007205556885250965
# epoch 725
# **********
# running_loss:-------
# 0.0007204651658182735
# epoch 726
# **********
# running_loss:-------
# 0.0007203754549673042
# epoch 727
# **********
# running_loss:-------
# 0.0007202865087554896
# epoch 728
# **********
# running_loss:-------
# 0.0007201984177175466
# epoch 729
# **********
# running_loss:-------
# 0.0007201110895234691
# epoch 730
# **********
# running_loss:-------
# 0.0007200244608700559
# epoch 731
# **********
# running_loss:-------
# 0.0007199385820846555
# epoch 732
# **********
# running_loss:-------
# 0.000719853402668093
# epoch 733
# **********
# running_loss:-------
# 0.0007197690233046906
# epoch 734
# **********
# running_loss:-------
# 0.0007196853221695588
# epoch 735
# **********
# running_loss:-------
# 0.0007196023261861106
# epoch 736
# **********
# running_loss:-------
# 0.0007195200789271413
# epoch 737
# **********
# running_loss:-------
# 0.0007194384972346171
# epoch 738
# **********
# running_loss:-------
# 0.000719357572754222
# epoch 739
# **********
# running_loss:-------
# 0.0007192773184381086
# epoch 740
# **********
# running_loss:-------
# 0.0007191977432864231
# epoch 741
# **********
# running_loss:-------
# 0.0007191188390574251
# epoch 742
# **********
# running_loss:-------
# 0.0007190405233396375
# epoch 743
# **********
# running_loss:-------
# 0.0007189628437822871
# epoch 744
# **********
# running_loss:-------
# 0.00071888583081049
# epoch 745
# **********
# running_loss:-------
# 0.0007188093897893969
# epoch 746
# **********
# running_loss:-------
# 0.0007187336037585403
# epoch 747
# **********
# running_loss:-------
# 0.0007186583768091857
# epoch 748
# **********
# running_loss:-------
# 0.0007185837540487154
# epoch 749
# **********
# running_loss:-------
# 0.0007185097379952741
# epoch 750
# **********
# running_loss:-------
# 0.000718436299444306
# epoch 751
# **********
# running_loss:-------
# 0.0007183635105391819
# epoch 752
# **********
# running_loss:-------
# 0.0007182912415391496
# epoch 753
# **********
# running_loss:-------
# 0.0007182195191839459
# epoch 754
# **********
# running_loss:-------
# 0.0007181483514723842
# epoch 755
# **********
# running_loss:-------
# 0.0007180777202441956
# epoch 756
# **********
# running_loss:-------
# 0.0007180075977938606
# epoch 757
# **********
# running_loss:-------
# 0.0007179380947123801
# epoch 758
# **********
# running_loss:-------
# 0.0007178690328869187
# epoch 759
# **********
# running_loss:-------
# 0.0007178004959258133
# epoch 760
# **********
# ...
# 0.0007020974011929836
# epoch 1534
# **********
# running_loss:-------
# 0.0007020910668616006
# epoch 1535
# **********
# running_loss:-------
# 0.0007020847649165241
# epoch 1536
# **********
# running_loss:-------
# 0.0007020784597511846
# epoch 1537
# **********
# running_loss:-------
# 0.0007020721971365695
# epoch 1538
# **********
# running_loss:-------
# 0.0007020659251159424
# epoch 1539
# **********
# running_loss:-------
# 0.0007020596573850493
# epoch 1540
# **********
# running_loss:-------
# 0.0007020534078736755
# epoch 1541
# **********
# running_loss:-------
# 0.0007020471682393549
# epoch 1542
# **********
# running_loss:-------
# 0.0007020409332532335
# epoch 1543
# **********
# running_loss:-------
# 0.0007020347075101853
# epoch 1544
# **********
# running_loss:-------
# 0.0007020285216012276
# epoch 1545
# **********
# running_loss:-------
# 0.0007020223345428108
# epoch 1546
# **********
# running_loss:-------
# 0.0007020161541263717
# epoch 1547
# **********
# running_loss:-------
# 0.0007020100000675036
# epoch 1548
# **********
# running_loss:-------
# 0.0007020038403028155
# epoch 1549
# **********
# running_loss:-------
# 0.0007019977100270858
# epoch 1550
# **********
# running_loss:-------
# 0.0007019915644528849
# epoch 1551
# **********
# running_loss:-------
# 0.0007019854500710937
# epoch 1552
# **********
# running_loss:-------
# 0.000701979315635981
# epoch 1553
# **********
# running_loss:-------
# 0.000701973227114057
# epoch 1554
# **********
# running_loss:-------
# 0.0007019671629855511
# epoch 1555
# **********
# running_loss:-------
# 0.0007019611029097772
# epoch 1556
# **********
# running_loss:-------
# 0.0007019550314194006
# epoch 1557
# **********
# running_loss:-------
# 0.000701949011023666
# epoch 1558
# **********
# running_loss:-------
# 0.0007019429553709397
# epoch 1559
# **********
# running_loss:-------
# 0.0007019369205980788
# epoch 1560
# **********
# running_loss:-------
# 0.0007019309227471477
# epoch 1561
# **********
# running_loss:-------
# 0.0007019248990481994
# epoch 1562
# **********
# running_loss:-------
# 0.0007019189260084023
# epoch 1563
# **********
# running_loss:-------
# 0.0007019129424427593
# epoch 1564
# **********
# running_loss:-------
# 0.0007019069702798692
# epoch 1565
# **********
# running_loss:-------
# 0.0007019010238376077
# epoch 1566
# **********
# running_loss:-------
# 0.0007018950843039509
# epoch 1567
# **********
# running_loss:-------
# 0.0007018891615352144
# epoch 1568
# **********
# running_loss:-------
# 0.0007018832167045656
# epoch 1569
# **********
# running_loss:-------
# 0.0007018773135566219
# epoch 1570
# **********
# running_loss:-------
# 0.0007018714102605521
# epoch 1571
# **********
# running_loss:-------
# 0.0007018655189982524
# epoch 1572
# **********
# running_loss:-------
# 0.0007018596276589273
# epoch 1573
# **********
# running_loss:-------
# 0.0007018537806893159
# epoch 1574
# **********
# running_loss:-------
# 0.0007018479064526387
# epoch 1575
# **********
# running_loss:-------
# 0.0007018420606176739
# epoch 1576
# **********
# running_loss:-------
# 0.0007018362432732971
# epoch 1577
# **********
# running_loss:-------
# 0.0007018304225279434
# epoch 1578
# **********
# running_loss:-------
# 0.0007018246214478205
# epoch 1579
# **********
# running_loss:-------
# 0.000701818805401029
# epoch 1580
# **********
# running_loss:-------
# 0.0007018130203688956
# epoch 1581
# **********
# running_loss:-------
# 0.000701807246366237
# epoch 1582
# **********
# running_loss:-------
# 0.0007018014831086511
# epoch 1583
# **********
# running_loss:-------
# 0.0007017957170307428
# epoch 1584
# **********
# running_loss:-------
# 0.0007017899640886635
# epoch 1585
# **********
# running_loss:-------
# 0.0007017842673989796
# epoch 1586
# **********
# running_loss:-------
# 0.000701778572187595
# epoch 1587
# **********
# running_loss:-------
# 0.0007017728441781131
# epoch 1588
# **********
# running_loss:-------
# 0.000701767176242682
# epoch 1589
# **********
# running_loss:-------
# 0.0007017614925170008
# epoch 1590
# **********
# running_loss:-------
# 0.0007017557879292293
# epoch 1591
# **********
# running_loss:-------
# 0.0007017501274889825
# epoch 1592
# **********
# running_loss:-------
# 0.0007017444699608963
# epoch 1593
# **********
# running_loss:-------
# 0.0007017388161359643
# epoch 1594
# **********
# running_loss:-------
# 0.0007017331794107178
# epoch 1595
# **********
# running_loss:-------
# 0.0007017275562686414
# epoch 1596
# **********
# running_loss:-------
# 0.0007017219353988203
# epoch 1597
# **********
# running_loss:-------
# 0.0007017163338446524
# epoch 1598
# **********
# running_loss:-------
# 0.0007017107525689574
# epoch 1599
# **********
# running_loss:-------
# 0.0007017051771857216
# epoch 1600
# **********
# running_loss:-------
# 0.0007016995899760921
# epoch 1601
# **********
# running_loss:-------
# 0.0007016940518880642
# epoch 1602
# **********
# running_loss:-------
# 0.000701688500465718
# epoch 1603
# **********
# running_loss:-------
# 0.000701682974301847
# epoch 1604
# **********
# running_loss:-------
# 0.0007016774104013522
# epoch 1605
# **********
# running_loss:-------
# 0.0007016718792900669
# epoch 1606
# **********
# running_loss:-------
# 0.0007016663806184135
# epoch 1607
# **********
# running_loss:-------
# 0.0007016608737346452
# epoch 1608
# **********
# running_loss:-------
# 0.0007016553629699711
# epoch 1609
# **********
# running_loss:-------
# 0.0007016498645797574
# epoch 1610
# **********
# running_loss:-------
# 0.00070164439601623
# epoch 1611
# **********
# running_loss:-------
# 0.0007016389195842402
# epoch 1612
# **********
# running_loss:-------
# 0.0007016334622190515
# epoch 1613
# **********
# running_loss:-------
# 0.0007016280098397896
# epoch 1614
# **********
# running_loss:-------
# 0.0007016225943232072
# epoch 1615
# **********
# running_loss:-------
# 0.0007016171944635612
# epoch 1616
# **********
# running_loss:-------
# 0.0007016117793380319
# epoch 1617
# **********
# running_loss:-------
# 0.0007016063771379925
# epoch 1618
# **********
# running_loss:-------
# 0.0007016009773138968
# epoch 1619
# **********
# running_loss:-------
# 0.0007015955972083574
# epoch 1620
# **********
# running_loss:-------
# 0.0007015902221242951
# epoch 1621
# **********
# running_loss:-------
# 0.0007015848410233477
# epoch 1622
# **********
# running_loss:-------
# 0.0007015794733781818
# epoch 1623
# **********
# running_loss:-------
# 0.0007015741305026747
# epoch 1624
# **********
# running_loss:-------
# 0.000701568789774997
# epoch 1625
# **********
# running_loss:-------
# 0.0007015634854152572
# epoch 1626
# **********
# running_loss:-------
# 0.0007015581747453426
# epoch 1627
# **********
# running_loss:-------
# 0.0007015528814476654
# epoch 1628
# **********
# running_loss:-------
# 0.0007015475797245716
# epoch 1629
# **********
# running_loss:-------
# 0.0007015422806944116
# epoch 1630
# **********
# running_loss:-------
# 0.0007015369930788545
# epoch 1631
# **********
# running_loss:-------
# 0.0007015317200152125
# epoch 1632
# **********
# running_loss:-------
# 0.0007015264254081001
# epoch 1633
# **********
# running_loss:-------
# 0.0007015211797092874
# epoch 1634
# **********
# running_loss:-------
# 0.0007015159616004556
# epoch 1635
# **********
# running_loss:-------
# 0.0007015107345536906
# epoch 1636
# **********
# running_loss:-------
# 0.0007015054988859823
# epoch 1637
# **********
# running_loss:-------
# 0.0007015002998646893
# epoch 1638
# **********
# running_loss:-------
# 0.0007014950835007838
# epoch 1639
# **********
# running_loss:-------
# 0.0007014898785722189
# epoch 1640
# **********
# running_loss:-------
# 0.0007014846952760003
# epoch 1641
# **********
# running_loss:-------
# 0.0007014795211339793
# epoch 1642
# **********
# running_loss:-------
# 0.0007014743473474609
# epoch 1643
# **********
# running_loss:-------
# 0.0007014691918782253
# epoch 1644
# **********
# running_loss:-------
# 0.0007014640424940126
# epoch 1645
# **********
# running_loss:-------
# 0.0007014588898421367
# epoch 1646
# **********
# running_loss:-------
# 0.0007014537575961223
# epoch 1647
# **********
# running_loss:-------
# 0.000701448615615256
# epoch 1648
# **********
# running_loss:-------
# 0.0007014435132374032
# epoch 1649
# **********
# running_loss:-------
# 0.0007014384084984191
# epoch 1650
# **********
# running_loss:-------
# 0.0007014333315064297
# epoch 1651
# **********
# running_loss:-------
# 0.0007014282590619139
# epoch 1652
# **********
# running_loss:-------
# 0.000701423172462461
# epoch 1653
# **********
# running_loss:-------
# 0.0007014181157430198
# epoch 1654
# **********
# running_loss:-------
# 0.0007014130405166944
# epoch 1655
# **********
# running_loss:-------
# 0.0007014079899148641
# epoch 1656
# **********
# running_loss:-------
# 0.0007014029609127922
# epoch 1657
# **********
# running_loss:-------
# 0.0007013979315848429
# epoch 1658
# **********
# running_loss:-------
# 0.0007013929076190609
# epoch 1659
# **********
# running_loss:-------
# 0.0007013878892939236
# epoch 1660
# **********
# running_loss:-------
# 0.0007013828808932399
# epoch 1661
# **********
# running_loss:-------
# 0.0007013778727028954
# epoch 1662
# **********
# running_loss:-------
# 0.0007013728882690265
# epoch 1663
# **********
# running_loss:-------
# 0.0007013679006652575
# epoch 1664
# **********
# running_loss:-------
# 0.0007013629288280383
# epoch 1665
# **********
# running_loss:-------
# 0.00070135796277959
# epoch 1666
# **********
# running_loss:-------
# 0.0007013530044544403
# epoch 1667
# **********
# running_loss:-------
# 0.0007013480513759198
# epoch 1668
# **********
# running_loss:-------
# 0.0007013431213162064
# epoch 1669
# **********
# running_loss:-------
# 0.0007013381797737521
# epoch 1670
# **********
# running_loss:-------
# 0.0007013332678831952
# epoch 1671
# **********
# running_loss:-------
# 0.0007013283692884434
# epoch 1672
# **********
# running_loss:-------
# 0.0007013234809025476
# epoch 1673
# **********
# running_loss:-------
# 0.0007013186058657825
# epoch 1674
# **********
# running_loss:-------
# 0.0007013137143336867
# epoch 1675
# **********
# running_loss:-------
# 0.000701308859243592
# epoch 1676
# **********
# running_loss:-------
# 0.0007013039811969029
# epoch 1677
# **********
# running_loss:-------
# 0.0007012991410349639
# epoch 1678
# **********
# running_loss:-------
# 0.0007012943004908595
# epoch 1679
# **********
# running_loss:-------
# 0.0007012894399556466
# epoch 1680
# **********
# running_loss:-------
# 0.0007012846251766087
# epoch 1681
# **********
# running_loss:-------
# 0.0007012798020165918
# epoch 1682
# **********
# running_loss:-------
# 0.0007012749846097955
# epoch 1683
# **********
# running_loss:-------
# 0.0007012701493626829
# epoch 1684
# **********
# running_loss:-------
# 0.0007012653495058755
# epoch 1685
# **********
# running_loss:-------
# 0.0007012605381752148
# epoch 1686
# **********
# running_loss:-------
# 0.0007012557775481431
# epoch 1687
# **********
# running_loss:-------
# 0.0007012510033586391
# epoch 1688
# **********
# running_loss:-------
# 0.0007012462425182657
# epoch 1689
# **********
# running_loss:-------
# 0.0007012414982502485
# epoch 1690
# **********
# running_loss:-------
# 0.0007012367383223322
# epoch 1691
# **********
# running_loss:-------
# 0.0007012319975323177
# epoch 1692
# **********
# running_loss:-------
# 0.0007012272604158321
# epoch 1693
# **********
# running_loss:-------
# 0.0007012225464159171
# epoch 1694
# **********
# running_loss:-------
# 0.0007012178147623248
# epoch 1695
# **********
# running_loss:-------
# 0.0007012131209520072
# epoch 1696
# **********
# running_loss:-------
# 0.0007012084124653484
# epoch 1697
# **********
# running_loss:-------
# 0.0007012037149815017
# epoch 1698
# **********
# running_loss:-------
# 0.0007011990353675964
# epoch 1699
# **********
# running_loss:-------
# 0.0007011943723230849
# epoch 1700
# **********
# running_loss:-------
# 0.0007011896868107956
# epoch 1701
# **********
# running_loss:-------
# 0.000701185028565572
# epoch 1702
# **********
# running_loss:-------
# 0.0007011803773533793
# epoch 1703
# **********
# running_loss:-------
# 0.000701175699063722
# epoch 1704
# **********
# running_loss:-------
# 0.0007011710730774164
# epoch 1705
# **********
# running_loss:-------
# 0.0007011664389263962
# epoch 1706
# **********
# running_loss:-------
# 0.0007011618128304772
# epoch 1707
# **********
# running_loss:-------
# 0.0007011572008391325
# epoch 1708
# **********
# running_loss:-------
# 0.0007011525975220565
# epoch 1709
# **********
# running_loss:-------
# 0.0007011479872163876
# epoch 1710
# **********
# running_loss:-------
# 0.0007011433916226102
# epoch 1711
# **********
# running_loss:-------
# 0.0007011388254466907
# epoch 1712
# **********
# running_loss:-------
# 0.0007011342290411819
# epoch 1713
# **********
# running_loss:-------
# 0.0007011296457418768
# epoch 1714
# **********
# running_loss:-------
# 0.0007011250591363956
# epoch 1715
# **********
# running_loss:-------
# 0.0007011205172739062
# epoch 1716
# **********
# running_loss:-------
# 0.000701115961689008
# epoch 1717
# **********
# running_loss:-------
# 0.000701111402691283
# epoch 1718
# **********
# running_loss:-------
# 0.0007011069004258821
# epoch 1719
# **********
# running_loss:-------
# 0.0007011023567621784
# epoch 1720
# **********
# running_loss:-------
# 0.000701097806948276
# epoch 1721
# **********
# running_loss:-------
# 0.0007010933109219495
# epoch 1722
# **********
# running_loss:-------
# 0.000701088814000941
# epoch 1723
# **********
# running_loss:-------
# 0.000701084323348632
# epoch 1724
# **********
# running_loss:-------
# 0.0007010798361950632
# epoch 1725
# **********
# running_loss:-------
# 0.0007010753338496743
# epoch 1726
# **********
# running_loss:-------
# 0.000701070852120486
# epoch 1727
# **********
# running_loss:-------
# 0.0007010663967725691
# epoch 1728
# **********
# running_loss:-------
# 0.0007010619218542223
# epoch 1729
# **********
# running_loss:-------
# 0.0007010574597399018
# epoch 1730
# **********
# running_loss:-------
# 0.0007010529846675038
# epoch 1731
# **********
# running_loss:-------
# 0.0007010485624791119
# epoch 1732
# **********
# running_loss:-------
# 0.000701044138122153
# epoch 1733
# **********
# running_loss:-------
# 0.0007010397096828367
# epoch 1734
# **********
# running_loss:-------
# 0.0007010352918937923
# epoch 1735
# **********
# running_loss:-------
# 0.000701030889980911
# epoch 1736
# **********
# running_loss:-------
# 0.0007010264821489078
# epoch 1737
# **********
# running_loss:-------
# 0.0007010220958396377
# epoch 1738
# **********
# running_loss:-------
# 0.0007010177124958534
# epoch 1739
# **********
# running_loss:-------
# 0.0007010133257807175
# epoch 1740
# **********
# running_loss:-------
# 0.0007010089864600319
# epoch 1741
# **********
# running_loss:-------
# 0.0007010046200529943
# epoch 1742
# **********
# running_loss:-------
# 0.0007010002497443132
# epoch 1743
# **********
# running_loss:-------
# 0.0007009959122811299
# epoch 1744
# **********
# running_loss:-------
# 0.0007009915497994359
# epoch 1745
# **********
# running_loss:-------
# 0.0007009872332427805
# epoch 1746
# **********
# running_loss:-------
# 0.0007009829057988515
# epoch 1747
# **********
# running_loss:-------
# 0.0007009785646265886
# epoch 1748
# **********
# running_loss:-------
# 0.0007009742650659304
# epoch 1749
# **********
# running_loss:-------
# 0.000700969944542456
# epoch 1750
# **********
# running_loss:-------
# 0.0007009656600610422
# epoch 1751
# **********
# running_loss:-------
# 0.0007009613349071437
# epoch 1752
# **********
# running_loss:-------
# 0.0007009570450517124
# epoch 1753
# **********
# running_loss:-------
# 0.0007009527675263035
# epoch 1754
# **********
# running_loss:-------
# 0.0007009485069228288
# epoch 1755
# **********
# running_loss:-------
# 0.0007009442227850675
# epoch 1756
# **********
# running_loss:-------
# 0.0007009399686635941
# epoch 1757
# **********
# running_loss:-------
# 0.0007009357240755211
# epoch 1758
# **********
# running_loss:-------
# 0.0007009314602280831
# epoch 1759
# **********
# running_loss:-------
# 0.0007009272184929202
# epoch 1760
# **********
# running_loss:-------
# 0.0007009229855179392
# epoch 1761
# **********
# running_loss:-------
# 0.0007009187253855056
# epoch 1762
# **********
# running_loss:-------
# 0.0007009145330563464
# epoch 1763
# **********
# running_loss:-------
# 0.0007009103188637642
# epoch 1764
# **********
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# E:\Anaconda\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# E:\Anaconda\lib\site-packages\torch\utils\data\_utils\collate.py in default_collate(batch)
#      41             storage = batch[0].storage()._new_shared(numel)
#      42             out = batch[0].new(storage)
# ---> 43         return torch.stack(batch, 0, out=out)
#      44     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
#      45             and elem_type.__name__ != 'string_':
#
# KeyboardInterrupt:

# %%
print(train_x.size(),train_y.size(),out.size())
out = model(train_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d680505c1d3a> in <module>
#       1
# ----> 2 print(train_x.size(),train_y.size(),out.size())
#       3 out = model(train_x)
#
# NameError: name 'train_x' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(losslist,'r-.') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-02e8ea6ca590> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(losslist,'r-.')
#       3 plt.show()
#
# NameError: name 'losslist' is not defined

# %% [raw]
# 0.00797845292009054

# %%
out.detach().numpy().shape
# Out:
# (100, 1)

# %%
x=range(0,100)
plt.figure(num=1,figsize=(18,5))#定义编号为1 大小为(8,5)
plt.plot(x,train_y.numpy(),'r-.',label='train_y') 
plt.plot(x,out.detach().numpy(),'b-.',label='out') 
plt.legend(loc='best')#显示在最好的位置
plt.show()

# %%
model.eval()
    
test_x=test_dataset[:,0:8]

test_x=test_x.view(-1,1,8)

test_y=test_dataset[:,8]

test_y=test_y.view(-1,1)

test_x=Variable(test_x)

test_y=Variable(test_y)

out = model(test_x)

# %%
#x=range(0,13123)
x=range(1200,1300)
plt.figure(num=1,figsize=(18,5))#定义编号为1 大小为(8,5)
plt.plot(x,test_y.numpy()[1200:1300],'r-.',label='test_y') 
plt.plot(x,out.detach().numpy()[1200:1300],'b-.',label='out') 
plt.legend(loc='best')#显示在最好的位置
plt.show()

# %%
# 保存模型
torch.save(model.state_dict(), './weatherlstm-0.01-false.pth')
