# %%
import pandas as pd
import time

# %%
def parse(x):
    return pd.datetime.strptime(x, '%Y %m %d %H')
df = pd.read_csv('test.csv',  parse_dates = {'date':[1,2,3,4]} ,index_col='No', date_parser=parse)
#print(df.dropna(axis=0,how='any'))#0对行进行操作 1对列进行操作 any:只要存在NaN即可drop掉 all:必须全部是NaN才可drop
df=df.dropna(axis=0,how='any')

# %%
CSV_FILE_PATH = './test.csv'
df = pd.read_csv(CSV_FILE_PATH, skiprows=0)
df
# Out:
#       No  year  month  day  hour  pm2.5  DEWP  TEMP  PRES cbwd    Iws  Is  Ir
# 0      1  2010      1    1     0    NaN   -21   -11  1021   NW   1.79   0   0
# 1      2  2010      1    1     1    NaN   -21   -12  1020   NW   4.92   0   0
# 2      3  2010      1    1     2    NaN   -21   -11  1019   NW   6.71   0   0
# 3      4  2010      1    1     3    NaN   -21   -14  1019   NW   9.84   0   0
# 4      5  2010      1    1     4    NaN   -20   -12  1018   NW  12.97   0   0
# 5      6  2010      1    1     5    NaN   -19   -10  1017   NW  16.10   0   0
# 6      7  2010      1    1     6    NaN   -19    -9  1017   NW  19.23   0   0
# 7      8  2010      1    1     7    NaN   -19    -9  1017   NW  21.02   0   0
# 8      9  2010      1    1     8    NaN   -19    -9  1017   NW  24.15   0   0
# 9     10  2010      1    1     9    NaN   -20    -8  1017   NW  27.28   0   0
# 10    11  2010      1    1    10    NaN   -19    -7  1017   NW  31.30   0   0
# ...
